# %% [markdown]
# # Catan RL Baseline — MaskablePPO
# Train a PPO agent with action masking on Catanatron, then evaluate win rate.

# %% [markdown]
# ## Cell 1: Imports & Setup

# %%
import gymnasium
import numpy as np
import time
from sb3_contrib.common.maskable.policies import MaskableActorCriticPolicy
from sb3_contrib.common.wrappers import ActionMasker
from sb3_contrib.ppo_mask import MaskablePPO
from stable_baselines3.common.callbacks import BaseCallback
import catanatron_gym
from catanatron import RandomPlayer, Color

print("Imports OK")
# Out:
# /opt/homebrew/lib/python3.11/site-packages/requests/__init__.py:113: RequestsDependencyWarning: urllib3 (2.3.0) or chardet (6.0.0dev0)/charset_normalizer (3.2.0) doesn't match a supported version!
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/pandas/core/computation/expressions.py:22: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.8.5' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# Imports OK

# %%
import torch
torch.distributions.Distribution.set_default_validate_args(False)

# %% [markdown]
# ## Cell 2: Safe Mask Function

# %%
def mask_fn(env) -> np.ndarray:
    """Safe mask — guarantees at least one valid action to prevent NaN crash."""
    valid_actions = env.unwrapped.get_valid_actions()
    mask = np.zeros(env.action_space.n, dtype=bool)
    if len(valid_actions) > 0:
        mask[valid_actions] = True
    else:
        # Fallback: allow all actions (prevents Simplex NaN error)
        mask[:] = True
    return mask

# %% [markdown]
# ## Cell 3: Logging Callback

# %%
class CatanLoggingCallback(BaseCallback):

    def __init__(self, log_freq=10_000, verbose=1):
        super().__init__(verbose)
        self.log_freq = log_freq
        self.start_time = None
        self.episode_rewards = []
        self.episode_lengths = []
        self.wins = 0
        self.losses = 0
        self.total_episodes = 0
        self._last_log_step = 0

    def _on_training_start(self):
        self.start_time = time.time()

    def _on_step(self) -> bool:
        infos = self.locals.get("infos", [])
        for info in infos:
            if "episode" in info:
                ep_reward = info["episode"]["r"]
                ep_length = info["episode"]["l"]
                self.episode_rewards.append(ep_reward)
                self.episode_lengths.append(ep_length)
                self.total_episodes += 1
                if ep_reward > 0:
                    self.wins += 1
                elif ep_reward < 0:
                    self.losses += 1

        if self.num_timesteps - self._last_log_step >= self.log_freq:
            if self.total_episodes > 0:
                self._print_stats()
            self._last_log_step = self.num_timesteps

        return True

    def _print_stats(self):
        elapsed = time.time() - self.start_time
        steps_per_sec = self.num_timesteps / elapsed
        total_steps = self.locals.get("total_timesteps", 1_000_000)
        remaining = total_steps - self.num_timesteps
        eta = remaining / steps_per_sec if steps_per_sec > 0 else 0

        recent_r = self.episode_rewards[-50:]
        recent_l = self.episode_lengths[-50:]
        recent_wins = sum(1 for r in recent_r if r > 0)

        eta_h, rem = divmod(int(eta), 3600)
        eta_m, eta_s = divmod(rem, 60)
        el_h, rem = divmod(int(elapsed), 3600)
        el_m, el_s = divmod(rem, 60)

        print(f"\n{'='*60}")
        print(f"  Step: {self.num_timesteps:,} / {total_steps:,} "
              f"({100*self.num_timesteps/total_steps:.1f}%)")
        print(f"  Elapsed: {el_h}h {el_m}m {el_s}s | "
              f"ETA: {eta_h}h {eta_m}m {eta_s}s")
        print(f"  Speed: {steps_per_sec:.0f} steps/s | "
              f"Episodes: {self.total_episodes}")
        print(f"  Overall win rate: {self.wins}/{self.total_episodes} "
              f"({100*self.wins/self.total_episodes:.1f}%)")
        print(f"  Last 50 ep: win {100*recent_wins/len(recent_r):.1f}% | "
              f"avg len {np.mean(recent_l):.0f} | "
              f"avg reward {np.mean(recent_r):.3f}")
        print(f"{'='*60}")

    def _on_training_end(self):
        elapsed = time.time() - self.start_time
        print(f"\n{'#'*60}")
        print(f"  TRAINING COMPLETE")
        print(f"  Total time: {elapsed/3600:.1f} hours")
        print(f"  Total episodes: {self.total_episodes}")
        print(f"  Final win rate: {100*self.wins/max(1,self.total_episodes):.1f}%")
        print(f"{'#'*60}")

# %% [markdown]
# ## Cell 4: Train

# %%
TOTAL_TIMESTEPS = 1_000_000
SAVE_PATH = "catan_ppo_baseline"

# 1v1 against RandomPlayer
train_env = gymnasium.make(
    "catanatron-v1",
    config={"enemies": [RandomPlayer(Color.RED)]},
)
train_env = ActionMasker(train_env, mask_fn)

model = MaskablePPO(
    MaskableActorCriticPolicy,
    train_env,
    verbose=1,
    learning_rate=3e-4,
    n_steps=2048,
    batch_size=64,
    n_epochs=10,
    gamma=0.999,
    ent_coef=0.01,
    tensorboard_log="./catan_tb/",
    policy_kwargs=dict(net_arch=[256, 256]),
)

print(f"Obs shape: {train_env.observation_space.shape}")
print(f"Action space: {train_env.action_space.n}")
print(f"Training for {TOTAL_TIMESTEPS:,} steps...\n")

callback = CatanLoggingCallback(log_freq=10_000)
model.learn(total_timesteps=TOTAL_TIMESTEPS, callback=callback)
model.save(SAVE_PATH)
train_env.close()

print(f"\nModel saved to {SAVE_PATH}.zip")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Obs shape: (614,)
# Action space: 290
# Training for 1,000,000 steps...
#
# Logging to ./catan_tb/PPO_5
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 376      |
# |    ep_rew_mean     | 0.2      |
# | time/              |          |
# |    fps             | 2800     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 426         |
# |    ep_rew_mean          | -0.111      |
# | time/                   |             |
# |    fps                  | 1500        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009971078 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.445      |
# |    explained_variance   | 0.298       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0369     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0175     |
# |    value_loss           | 0.00878     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 434         |
# |    ep_rew_mean          | -0.286      |
# | time/                   |             |
# |    fps                  | 1360        |
# |    iterations           | 3           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010322527 |
# |    clip_fraction        | 0.0844      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.368      |
# |    explained_variance   | -0.0342     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.028      |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0115     |
# |    value_loss           | 0.00555     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 470         |
# |    ep_rew_mean          | -0.176      |
# | time/                   |             |
# |    fps                  | 1302        |
# |    iterations           | 4           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.019057887 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.478      |
# |    explained_variance   | 0.904       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00487    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0205     |
# |    value_loss           | 0.00294     |
# -----------------------------------------
#
# ============================================================
#   Step: 10,000 / 1,000,000 (1.0%)
#   Elapsed: 0h 0m 8s | ETA: 0h 13m 17s
#   Speed: 1241 steps/s | Episodes: 19
#   Overall win rate: 7/19 (36.8%)
#   Last 50 ep: win 36.8% | avg len 476 | avg reward -0.263
# ============================================================
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 476         |
# |    ep_rew_mean          | -0.263      |
# | time/                   |             |
# |    fps                  | 1257        |
# |    iterations           | 5           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.012831213 |
# |    clip_fraction        | 0.096       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.407      |
# |    explained_variance   | 0.749       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0155     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0118     |
# |    value_loss           | 0.00793     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 487         |
# |    ep_rew_mean          | -0.08       |
# | time/                   |             |
# |    fps                  | 1234        |
# |    iterations           | 6           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.015344225 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.413      |
# |    explained_variance   | 0.898       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0235     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0141     |
# |    value_loss           | 0.00157     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 482         |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 1224        |
# |    iterations           | 7           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.024211459 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.561      |
# |    explained_variance   | 0.391       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00461    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0167     |
# |    value_loss           | 0.00377     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 499         |
# |    ep_rew_mean          | -0.0323     |
# | time/                   |             |
# |    fps                  | 1215        |
# |    iterations           | 8           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.021527596 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.465      |
# |    explained_variance   | 0.53        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0326     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0153     |
# |    value_loss           | 0.00144     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 491         |
# |    ep_rew_mean          | 0.027       |
# | time/                   |             |
# |    fps                  | 1209        |
# |    iterations           | 9           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.019613702 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.339      |
# |    explained_variance   | 0.792       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0211     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0123     |
# |    value_loss           | 0.000744    |
# -----------------------------------------
#
# ============================================================
#   Step: 20,000 / 1,000,000 (2.0%)
#   Elapsed: 0h 0m 16s | ETA: 0h 13m 46s
#   Speed: 1186 steps/s | Episodes: 40
#   Overall win rate: 20/40 (50.0%)
#   Last 50 ep: win 50.0% | avg len 495 | avg reward 0.050
# ============================================================
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 492        |
# |    ep_rew_mean          | 0.0244     |
# | time/                   |            |
# |    fps                  | 1203       |
# |    iterations           | 10         |
# |    time_elapsed         | 17         |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.02403443 |
# |    clip_fraction        | 0.161      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.518     |
# |    explained_variance   | 0.386      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00307   |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.0187    |
# |    value_loss           | 0.00582    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 475        |
# |    ep_rew_mean          | 0.106      |
# | time/                   |            |
# |    fps                  | 1195       |
# |    iterations           | 11         |
# |    time_elapsed         | 18         |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.02145433 |
# |    clip_fraction        | 0.127      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.43      |
# |    explained_variance   | 0.815      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.034     |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.0153    |
# |    value_loss           | 0.0019     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 485         |
# |    ep_rew_mean          | 0.08        |
# | time/                   |             |
# |    fps                  | 1193        |
# |    iterations           | 12          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.035495814 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.481      |
# |    explained_variance   | 0.357       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0452     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.019      |
# |    value_loss           | 0.00388     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 482         |
# |    ep_rew_mean          | 0.0909      |
# | time/                   |             |
# |    fps                  | 1189        |
# |    iterations           | 13          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.017521225 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.366      |
# |    explained_variance   | 0.786       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0135     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0104     |
# |    value_loss           | 0.00269     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 498        |
# |    ep_rew_mean          | 0.0877     |
# | time/                   |            |
# |    fps                  | 1188       |
# |    iterations           | 14         |
# |    time_elapsed         | 24         |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.02794969 |
# |    clip_fraction        | 0.142      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.45      |
# |    explained_variance   | 0.769      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0249    |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.0136    |
# |    value_loss           | 0.00166    |
# ----------------------------------------
#
# ============================================================
#   Step: 30,000 / 1,000,000 (3.0%)
#   Elapsed: 0h 0m 25s | ETA: 0h 13m 49s
#   Speed: 1169 steps/s | Episodes: 61
#   Overall win rate: 30/61 (49.2%)
#   Last 50 ep: win 52.0% | avg len 502 | avg reward 0.080
# ============================================================
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 485         |
# |    ep_rew_mean          | 0.0159      |
# | time/                   |             |
# |    fps                  | 1186        |
# |    iterations           | 15          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.029658174 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.359      |
# |    explained_variance   | 0.905       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0143     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0128     |
# |    value_loss           | 0.0011      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 480         |
# |    ep_rew_mean          | 0.0746      |
# | time/                   |             |
# |    fps                  | 1183        |
# |    iterations           | 16          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.015813641 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.402      |
# |    explained_variance   | 0.455       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0191     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 0.00397     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 474        |
# |    ep_rew_mean          | 0.0959     |
# | time/                   |            |
# |    fps                  | 1181       |
# |    iterations           | 17         |
# |    time_elapsed         | 29         |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.03461621 |
# |    clip_fraction        | 0.156      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.41      |
# |    explained_variance   | 0.706      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0278    |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.0205    |
# |    value_loss           | 0.00199    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 477         |
# |    ep_rew_mean          | 0.0649      |
# | time/                   |             |
# |    fps                  | 1179        |
# |    iterations           | 18          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.035439193 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.538      |
# |    explained_variance   | 0.614       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0602     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0185     |
# |    value_loss           | 0.00293     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 477         |
# |    ep_rew_mean          | 0.0617      |
# | time/                   |             |
# |    fps                  | 1179        |
# |    iterations           | 19          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.023364583 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.325      |
# |    explained_variance   | 0.964       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.027      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0126     |
# |    value_loss           | 0.000975    |
# -----------------------------------------
#
# ============================================================
#   Step: 40,000 / 1,000,000 (4.0%)
#   Elapsed: 0h 0m 34s | ETA: 0h 13m 47s
#   Speed: 1160 steps/s | Episodes: 84
#   Overall win rate: 43/84 (51.2%)
#   Last 50 ep: win 54.0% | avg len 452 | avg reward 0.080
# ============================================================
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 475        |
# |    ep_rew_mean          | 0.0698     |
# | time/                   |            |
# |    fps                  | 1178       |
# |    iterations           | 20         |
# |    time_elapsed         | 34         |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.02605604 |
# |    clip_fraction        | 0.129      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.4       |
# |    explained_variance   | 0.924      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0102    |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.0166    |
# |    value_loss           | 0.000913   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 480         |
# |    ep_rew_mean          | 0.0674      |
# | time/                   |             |
# |    fps                  | 1176        |
# |    iterations           | 21          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.027527936 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.352      |
# |    explained_variance   | 0.919       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0363     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0162     |
# |    value_loss           | 0.001       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 482        |
# |    ep_rew_mean          | 0.0645     |
# | time/                   |            |
# |    fps                  | 1174       |
# |    iterations           | 22         |
# |    time_elapsed         | 38         |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.02507816 |
# |    clip_fraction        | 0.111      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.344     |
# |    explained_variance   | 0.833      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.016     |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.0125    |
# |    value_loss           | 0.00132    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 479         |
# |    ep_rew_mean          | 0.0619      |
# | time/                   |             |
# |    fps                  | 1172        |
# |    iterations           | 23          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.016125567 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.349      |
# |    explained_variance   | 0.905       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00369    |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00766    |
# |    value_loss           | 0.00156     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 486        |
# |    ep_rew_mean          | 0.09       |
# | time/                   |            |
# |    fps                  | 1172       |
# |    iterations           | 24         |
# |    time_elapsed         | 41         |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.03535749 |
# |    clip_fraction        | 0.153      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.412     |
# |    explained_variance   | 0.775      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0108    |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.0168    |
# |    value_loss           | 0.00552    |
# ----------------------------------------
#
# ============================================================
#   Step: 50,000 / 1,000,000 (5.0%)
#   Elapsed: 0h 0m 43s | ETA: 0h 13m 42s
#   Speed: 1155 steps/s | Episodes: 104
#   Overall win rate: 54/104 (51.9%)
#   Last 50 ep: win 52.0% | avg len 473 | avg reward 0.060
# ============================================================
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 484         |
# |    ep_rew_mean          | 0.09        |
# | time/                   |             |
# |    fps                  | 1172        |
# |    iterations           | 25          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.046132866 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.354      |
# |    explained_variance   | 0.954       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0195     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0148     |
# |    value_loss           | 0.00157     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 485        |
# |    ep_rew_mean          | 0.11       |
# | time/                   |            |
# |    fps                  | 1169       |
# |    iterations           | 26         |
# |    time_elapsed         | 45         |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.03151087 |
# |    clip_fraction        | 0.136      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.396     |
# |    explained_variance   | 0.597      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0113    |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.0132    |
# |    value_loss           | 0.00385    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 474         |
# |    ep_rew_mean          | 0.13        |
# | time/                   |             |
# |    fps                  | 1165        |
# |    iterations           | 27          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.032707177 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.301      |
# |    explained_variance   | 0.961       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0321     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0154     |
# |    value_loss           | 0.00111     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 478         |
# |    ep_rew_mean          | 0.13        |
# | time/                   |             |
# |    fps                  | 1163        |
# |    iterations           | 28          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.036220502 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.407      |
# |    explained_variance   | 0.895       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0119     |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.014      |
# |    value_loss           | 0.00162     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 471         |
# |    ep_rew_mean          | 0.06        |
# | time/                   |             |
# |    fps                  | 1163        |
# |    iterations           | 29          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.028709883 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.323      |
# |    explained_variance   | 0.888       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0211     |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0126     |
# |    value_loss           | 0.00256     |
# -----------------------------------------
#
# ============================================================
#   Step: 60,000 / 1,000,000 (6.0%)
#   Elapsed: 0h 0m 52s | ETA: 0h 13m 40s
#   Speed: 1145 steps/s | Episodes: 126
#   Overall win rate: 64/126 (50.8%)
#   Last 50 ep: win 48.0% | avg len 472 | avg reward -0.020
# ============================================================
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 477         |
# |    ep_rew_mean          | 0.03        |
# | time/                   |             |
# |    fps                  | 1163        |
# |    iterations           | 30          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.027273107 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.303      |
# |    explained_variance   | 0.896       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0217     |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0133     |
# |    value_loss           | 0.00164     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 462         |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 1163        |
# |    iterations           | 31          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.022404833 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.332      |
# |    explained_variance   | 0.973       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0305     |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.013      |
# |    value_loss           | 0.000842    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 466         |
# |    ep_rew_mean          | -0.06       |
# | time/                   |             |
# |    fps                  | 1163        |
# |    iterations           | 32          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.020516839 |
# |    clip_fraction        | 0.0958      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.264      |
# |    explained_variance   | 0.909       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.019      |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0101     |
# |    value_loss           | 0.0014      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 467        |
# |    ep_rew_mean          | -0.06      |
# | time/                   |            |
# |    fps                  | 1162       |
# |    iterations           | 33         |
# |    time_elapsed         | 58         |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.01695754 |
# |    clip_fraction        | 0.0933     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.279     |
# |    explained_variance   | 0.777      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0104    |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.00931   |
# |    value_loss           | 0.00171    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 475         |
# |    ep_rew_mean          | -0.1        |
# | time/                   |             |
# |    fps                  | 1161        |
# |    iterations           | 34          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.025918938 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.281      |
# |    explained_variance   | 0.925       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0246     |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 0.0014      |
# -----------------------------------------
#
# ============================================================
#   Step: 70,000 / 1,000,000 (7.0%)
#   Elapsed: 0h 1m 1s | ETA: 0h 13m 33s
#   Speed: 1143 steps/s | Episodes: 147
#   Overall win rate: 68/147 (46.3%)
#   Last 50 ep: win 36.0% | avg len 466 | avg reward -0.260
# ============================================================
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 466         |
# |    ep_rew_mean          | -0.12       |
# | time/                   |             |
# |    fps                  | 1159        |
# |    iterations           | 35          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.028312832 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.28       |
# |    explained_variance   | 0.936       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0263     |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.013      |
# |    value_loss           | 0.00158     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 470         |
# |    ep_rew_mean          | -0.16       |
# | time/                   |             |
# |    fps                  | 1158        |
# |    iterations           | 36          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.032939155 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.294      |
# |    explained_variance   | 0.938       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.006      |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0152     |
# |    value_loss           | 0.00115     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 466         |
# |    ep_rew_mean          | -0.16       |
# | time/                   |             |
# |    fps                  | 1157        |
# |    iterations           | 37          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.018536191 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.257      |
# |    explained_variance   | 0.94        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00521    |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00966    |
# |    value_loss           | 0.00119     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 473        |
# |    ep_rew_mean          | -0.14      |
# | time/                   |            |
# |    fps                  | 1157       |
# |    iterations           | 38         |
# |    time_elapsed         | 67         |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.02433893 |
# |    clip_fraction        | 0.111      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.315     |
# |    explained_variance   | 0.825      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00884   |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.00975   |
# |    value_loss           | 0.00295    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 487         |
# |    ep_rew_mean          | -0.16       |
# | time/                   |             |
# |    fps                  | 1157        |
# |    iterations           | 39          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.024213383 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.284      |
# |    explained_variance   | 0.606       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0199     |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0101     |
# |    value_loss           | 0.00181     |
# -----------------------------------------
#
# ============================================================
#   Step: 80,000 / 1,000,000 (8.0%)
#   Elapsed: 0h 1m 10s | ETA: 0h 13m 27s
#   Speed: 1140 steps/s | Episodes: 165
#   Overall win rate: 74/165 (44.8%)
#   Last 50 ep: win 26.0% | avg len 500 | avg reward -0.460
# ============================================================
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 490         |
# |    ep_rew_mean          | -0.2        |
# | time/                   |             |
# |    fps                  | 1157        |
# |    iterations           | 40          |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.026708085 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.307      |
# |    explained_variance   | 0.76        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0118     |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 0.00142     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 493         |
# |    ep_rew_mean          | -0.22       |
# | time/                   |             |
# |    fps                  | 1157        |
# |    iterations           | 41          |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.027679361 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.298      |
# |    explained_variance   | 0.643       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0132     |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00939    |
# |    value_loss           | 0.00272     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 490        |
# |    ep_rew_mean          | -0.18      |
# | time/                   |            |
# |    fps                  | 1155       |
# |    iterations           | 42         |
# |    time_elapsed         | 74         |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.02841207 |
# |    clip_fraction        | 0.117      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.312     |
# |    explained_variance   | 0.513      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0299    |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.0124    |
# |    value_loss           | 0.00217    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 492         |
# |    ep_rew_mean          | -0.18       |
# | time/                   |             |
# |    fps                  | 1155        |
# |    iterations           | 43          |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.035883747 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.379      |
# |    explained_variance   | 0.918       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.019      |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0144     |
# |    value_loss           | 0.00208     |
# -----------------------------------------
#
# ============================================================
#   Step: 90,000 / 1,000,000 (9.0%)
#   Elapsed: 0h 1m 17s | ETA: 0h 13m 8s
#   Speed: 1154 steps/s | Episodes: 185
#   Overall win rate: 84/185 (45.4%)
#   Last 50 ep: win 38.0% | avg len 517 | avg reward -0.240
# ============================================================
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 495        |
# |    ep_rew_mean          | -0.18      |
# | time/                   |            |
# |    fps                  | 1155       |
# |    iterations           | 44         |
# |    time_elapsed         | 78         |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.02723968 |
# |    clip_fraction        | 0.141      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.368     |
# |    explained_variance   | 0.833      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0232    |
# |    n_updates            | 430        |
# |    policy_gradient_loss | -0.0117    |
# |    value_loss           | 0.00166    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 483         |
# |    ep_rew_mean          | -0.23       |
# | time/                   |             |
# |    fps                  | 1155        |
# |    iterations           | 45          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.035570942 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.369      |
# |    explained_variance   | 0.865       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0186     |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0127     |
# |    value_loss           | 0.0061      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 483         |
# |    ep_rew_mean          | -0.21       |
# | time/                   |             |
# |    fps                  | 1154        |
# |    iterations           | 46          |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.026490841 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.347      |
# |    explained_variance   | 0.608       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0182     |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00888    |
# |    value_loss           | 0.00233     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 474        |
# |    ep_rew_mean          | -0.23      |
# | time/                   |            |
# |    fps                  | 1154       |
# |    iterations           | 47         |
# |    time_elapsed         | 83         |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.04961154 |
# |    clip_fraction        | 0.139      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.322     |
# |    explained_variance   | 0.936      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0346    |
# |    n_updates            | 460        |
# |    policy_gradient_loss | -0.0154    |
# |    value_loss           | 0.00189    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 481         |
# |    ep_rew_mean          | -0.26       |
# | time/                   |             |
# |    fps                  | 1154        |
# |    iterations           | 48          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.033879198 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.285      |
# |    explained_variance   | 0.923       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0185     |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0143     |
# |    value_loss           | 0.00104     |
# -----------------------------------------
#
# ============================================================
#   Step: 100,000 / 1,000,000 (10.0%)
#   Elapsed: 0h 1m 26s | ETA: 0h 13m 1s
#   Speed: 1152 steps/s | Episodes: 210
#   Overall win rate: 93/210 (44.3%)
#   Last 50 ep: win 42.0% | avg len 470 | avg reward -0.140
# ============================================================
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 469         |
# |    ep_rew_mean          | -0.3        |
# | time/                   |             |
# |    fps                  | 1154        |
# |    iterations           | 49          |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.037606604 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.288      |
# |    explained_variance   | 0.895       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0128     |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0107     |
# |    value_loss           | 0.00124     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 474         |
# |    ep_rew_mean          | -0.34       |
# | time/                   |             |
# |    fps                  | 1154        |
# |    iterations           | 50          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.038047947 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.354      |
# |    explained_variance   | 0.894       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0405     |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0135     |
# |    value_loss           | 0.00165     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 471         |
# |    ep_rew_mean          | -0.3        |
# | time/                   |             |
# |    fps                  | 1154        |
# |    iterations           | 51          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.032518975 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.254      |
# |    explained_variance   | 0.762       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0355     |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00994    |
# |    value_loss           | 0.00134     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 476         |
# |    ep_rew_mean          | -0.26       |
# | time/                   |             |
# |    fps                  | 1153        |
# |    iterations           | 52          |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 106496      |
# ...
# |    approx_kl            | 0.05228335 |
# |    clip_fraction        | 0.127      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.227     |
# |    explained_variance   | 0.961      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0285    |
# |    n_updates            | 4720       |
# |    policy_gradient_loss | -0.0203    |
# |    value_loss           | 0.00273    |
# ----------------------------------------
#
# ============================================================
#   Step: 970,000 / 1,000,000 (97.0%)
#   Elapsed: 0h 14m 5s | ETA: 0h 0m 26s
#   Speed: 1147 steps/s | Episodes: 2566
#   Overall win rate: 1719/2566 (67.0%)
#   Last 50 ep: win 86.0% | avg len 273 | avg reward 0.720
# ============================================================
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 293        |
# |    ep_rew_mean          | 0.72       |
# | time/                   |            |
# |    fps                  | 1147       |
# |    iterations           | 474        |
# |    time_elapsed         | 845        |
# |    total_timesteps      | 970752     |
# | train/                  |            |
# |    approx_kl            | 0.03288786 |
# |    clip_fraction        | 0.101      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.179     |
# |    explained_variance   | 0.96       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0344    |
# |    n_updates            | 4730       |
# |    policy_gradient_loss | -0.0147    |
# |    value_loss           | 0.0015     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 287         |
# |    ep_rew_mean          | 0.68        |
# | time/                   |             |
# |    fps                  | 1147        |
# |    iterations           | 475         |
# |    time_elapsed         | 847         |
# |    total_timesteps      | 972800      |
# | train/                  |             |
# |    approx_kl            | 0.025504362 |
# |    clip_fraction        | 0.0685      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.126      |
# |    explained_variance   | 0.956       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0109     |
# |    n_updates            | 4740        |
# |    policy_gradient_loss | -0.01       |
# |    value_loss           | 0.000526    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 297         |
# |    ep_rew_mean          | 0.68        |
# | time/                   |             |
# |    fps                  | 1147        |
# |    iterations           | 476         |
# |    time_elapsed         | 849         |
# |    total_timesteps      | 974848      |
# | train/                  |             |
# |    approx_kl            | 0.029079713 |
# |    clip_fraction        | 0.0935      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.157      |
# |    explained_variance   | 0.842       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0463     |
# |    n_updates            | 4750        |
# |    policy_gradient_loss | -0.0153     |
# |    value_loss           | 0.00287     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 299         |
# |    ep_rew_mean          | 0.68        |
# | time/                   |             |
# |    fps                  | 1147        |
# |    iterations           | 477         |
# |    time_elapsed         | 851         |
# |    total_timesteps      | 976896      |
# | train/                  |             |
# |    approx_kl            | 0.036644667 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.154      |
# |    explained_variance   | 0.882       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0202     |
# |    n_updates            | 4760        |
# |    policy_gradient_loss | -0.0117     |
# |    value_loss           | 0.000677    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 0.7         |
# | time/                   |             |
# |    fps                  | 1147        |
# |    iterations           | 478         |
# |    time_elapsed         | 852         |
# |    total_timesteps      | 978944      |
# | train/                  |             |
# |    approx_kl            | 0.029428817 |
# |    clip_fraction        | 0.0916      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.161      |
# |    explained_variance   | 0.954       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0219     |
# |    n_updates            | 4770        |
# |    policy_gradient_loss | -0.0121     |
# |    value_loss           | 0.00121     |
# -----------------------------------------
#
# ============================================================
#   Step: 980,000 / 1,000,000 (98.0%)
#   Elapsed: 0h 14m 14s | ETA: 0h 0m 17s
#   Speed: 1147 steps/s | Episodes: 2595
#   Overall win rate: 1742/2595 (67.1%)
#   Last 50 ep: win 80.0% | avg len 320 | avg reward 0.600
# ============================================================
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 304        |
# |    ep_rew_mean          | 0.64       |
# | time/                   |            |
# |    fps                  | 1147       |
# |    iterations           | 479        |
# |    time_elapsed         | 854        |
# |    total_timesteps      | 980992     |
# | train/                  |            |
# |    approx_kl            | 0.03715685 |
# |    clip_fraction        | 0.104      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.178     |
# |    explained_variance   | 0.886      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0133    |
# |    n_updates            | 4780       |
# |    policy_gradient_loss | -0.0164    |
# |    value_loss           | 0.00061    |
# ----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 309      |
# |    ep_rew_mean          | 0.62     |
# | time/                   |          |
# |    fps                  | 1147     |
# |    iterations           | 480      |
# |    time_elapsed         | 856      |
# |    total_timesteps      | 983040   |
# | train/                  |          |
# |    approx_kl            | 0.045241 |
# |    clip_fraction        | 0.112    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.187   |
# |    explained_variance   | 0.642    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.0176  |
# |    n_updates            | 4790     |
# |    policy_gradient_loss | -0.0176  |
# |    value_loss           | 0.00422  |
# --------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 306         |
# |    ep_rew_mean          | 0.68        |
# | time/                   |             |
# |    fps                  | 1147        |
# |    iterations           | 481         |
# |    time_elapsed         | 858         |
# |    total_timesteps      | 985088      |
# | train/                  |             |
# |    approx_kl            | 0.035703667 |
# |    clip_fraction        | 0.0882      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.149      |
# |    explained_variance   | 0.948       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0118     |
# |    n_updates            | 4800        |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 0.00104     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 307         |
# |    ep_rew_mean          | 0.66        |
# | time/                   |             |
# |    fps                  | 1147        |
# |    iterations           | 482         |
# |    time_elapsed         | 859         |
# |    total_timesteps      | 987136      |
# | train/                  |             |
# |    approx_kl            | 0.054078095 |
# |    clip_fraction        | 0.0972      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.153      |
# |    explained_variance   | 0.865       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00819    |
# |    n_updates            | 4810        |
# |    policy_gradient_loss | -0.0118     |
# |    value_loss           | 0.000631    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 315         |
# |    ep_rew_mean          | 0.64        |
# | time/                   |             |
# |    fps                  | 1148        |
# |    iterations           | 483         |
# |    time_elapsed         | 861         |
# |    total_timesteps      | 989184      |
# | train/                  |             |
# |    approx_kl            | 0.049621485 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.209      |
# |    explained_variance   | 0.795       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0176     |
# |    n_updates            | 4820        |
# |    policy_gradient_loss | -0.0151     |
# |    value_loss           | 0.00238     |
# -----------------------------------------
#
# ============================================================
#   Step: 990,000 / 1,000,000 (99.0%)
#   Elapsed: 0h 14m 22s | ETA: 0h 0m 8s
#   Speed: 1147 steps/s | Episodes: 2627
#   Overall win rate: 1769/2627 (67.3%)
#   Last 50 ep: win 84.0% | avg len 349 | avg reward 0.680
# ============================================================
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 310         |
# |    ep_rew_mean          | 0.64        |
# | time/                   |             |
# |    fps                  | 1148        |
# |    iterations           | 484         |
# |    time_elapsed         | 863         |
# |    total_timesteps      | 991232      |
# | train/                  |             |
# |    approx_kl            | 0.044721328 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.201      |
# |    explained_variance   | 0.89        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0257     |
# |    n_updates            | 4830        |
# |    policy_gradient_loss | -0.0149     |
# |    value_loss           | 0.00123     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 310        |
# |    ep_rew_mean          | 0.66       |
# | time/                   |            |
# |    fps                  | 1148       |
# |    iterations           | 485        |
# |    time_elapsed         | 865        |
# |    total_timesteps      | 993280     |
# | train/                  |            |
# |    approx_kl            | 0.03660732 |
# |    clip_fraction        | 0.0831     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.153     |
# |    explained_variance   | 0.84       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00674   |
# |    n_updates            | 4840       |
# |    policy_gradient_loss | -0.00852   |
# |    value_loss           | 0.000799   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 315         |
# |    ep_rew_mean          | 0.66        |
# | time/                   |             |
# |    fps                  | 1148        |
# |    iterations           | 486         |
# |    time_elapsed         | 866         |
# |    total_timesteps      | 995328      |
# | train/                  |             |
# |    approx_kl            | 0.045390904 |
# |    clip_fraction        | 0.099       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.149      |
# |    explained_variance   | 0.904       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0187     |
# |    n_updates            | 4850        |
# |    policy_gradient_loss | -0.0143     |
# |    value_loss           | 0.000606    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 319        |
# |    ep_rew_mean          | 0.6        |
# | time/                   |            |
# |    fps                  | 1148       |
# |    iterations           | 487        |
# |    time_elapsed         | 868        |
# |    total_timesteps      | 997376     |
# | train/                  |            |
# |    approx_kl            | 0.03655781 |
# |    clip_fraction        | 0.108      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.165     |
# |    explained_variance   | 0.962      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0306    |
# |    n_updates            | 4860       |
# |    policy_gradient_loss | -0.0151    |
# |    value_loss           | 0.00137    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 310        |
# |    ep_rew_mean          | 0.6        |
# | time/                   |            |
# |    fps                  | 1148       |
# |    iterations           | 488        |
# |    time_elapsed         | 870        |
# |    total_timesteps      | 999424     |
# | train/                  |            |
# |    approx_kl            | 0.04550218 |
# |    clip_fraction        | 0.079      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.142     |
# |    explained_variance   | 0.809      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0138    |
# |    n_updates            | 4870       |
# |    policy_gradient_loss | -0.0143    |
# |    value_loss           | 0.00227    |
# ----------------------------------------
#
# ============================================================
#   Step: 1,000,000 / 1,000,000 (100.0%)
#   Elapsed: 0h 14m 31s | ETA: 0h 0m 0s
#   Speed: 1147 steps/s | Episodes: 2661
#   Overall win rate: 1795/2661 (67.5%)
#   Last 50 ep: win 78.0% | avg len 298 | avg reward 0.560
# ============================================================
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 316         |
# |    ep_rew_mean          | 0.6         |
# | time/                   |             |
# |    fps                  | 1148        |
# |    iterations           | 489         |
# |    time_elapsed         | 872         |
# |    total_timesteps      | 1001472     |
# | train/                  |             |
# |    approx_kl            | 0.074817345 |
# |    clip_fraction        | 0.0844      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.145      |
# |    explained_variance   | 0.893       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00541    |
# |    n_updates            | 4880        |
# |    policy_gradient_loss | -0.0138     |
# |    value_loss           | 0.00144     |
# -----------------------------------------
#
# ############################################################
#   TRAINING COMPLETE
#   Total time: 0.2 hours
#   Total episodes: 2666
#   Final win rate: 67.5%
# ############################################################
#
# Model saved to catan_ppo_baseline.zip

# %%
import matplotlib.pyplot as plt

rewards = callback.episode_rewards
lengths = callback.episode_lengths

window = 50

if len(rewards) >= window:
    smoothed = np.convolve(rewards, np.ones(window)/window, mode='valid')
    smoothed_len = np.convolve(lengths, np.ones(window)/window, mode='valid')
    wins_binary = [1 if r > 0 else 0 for r in rewards]
    win_rate = np.convolve(wins_binary, np.ones(window)/window, mode='valid')

    fig, axes = plt.subplots(1, 3, figsize=(18, 5))

    axes[0].plot(smoothed)
    axes[0].set_title("Episode Reward (50-ep rolling avg)")
    axes[0].set_xlabel("Episode")
    axes[0].set_ylabel("Reward")
    axes[0].axhline(y=0, color='gray', linestyle='--', alpha=0.5)

    axes[1].plot(smoothed_len)
    axes[1].set_title("Episode Length (50-ep rolling avg)")
    axes[1].set_xlabel("Episode")
    axes[1].set_ylabel("Steps")

    axes[2].plot(100 * win_rate)
    axes[2].set_title("Win Rate (50-ep rolling avg)")
    axes[2].set_xlabel("Episode")
    axes[2].set_ylabel("Win Rate %")
    axes[2].axhline(y=50, color='red', linestyle='--', alpha=0.5, label='50%')
    axes[2].legend()

    plt.tight_layout()
    plt.show()

    print(f"Total episodes: {len(rewards)}")
    print(f"Final 50-ep win rate: {100*win_rate[-1]:.1f}%")
    print(f"Final 50-ep avg reward: {smoothed[-1]:.3f}")
else:
    print(f"Only {len(rewards)} episodes, need {window} to plot")
# Out:
# Total episodes: 2666
# Final 50-ep win rate: 80.0%
# Final 50-ep avg reward: 0.600

# %% [markdown]
# ## Cell 5: Evaluate

# %%
SAVE_PATH = "catan_ppo_baseline"  # must match training
N_GAMES = 500

model = MaskablePPO.load(SAVE_PATH)

eval_env = gymnasium.make(
    "catanatron-v1",
    config={"enemies": [RandomPlayer(Color.RED)]},
)

wins, losses, draws = 0, 0, 0
ep_lengths = []
ep_rewards = []

print(f"Evaluating over {N_GAMES} games...")
start = time.time()

for i in range(N_GAMES):
    obs, info = eval_env.reset()
    done = False
    total_reward = 0
    steps = 0

    while not done:
        valid = eval_env.unwrapped.get_valid_actions()
        mask = np.zeros(eval_env.action_space.n, dtype=bool)
        if len(valid) > 0:
            mask[valid] = True
        else:
            mask[:] = True

        action, _ = model.predict(obs, action_masks=mask, deterministic=True)
        obs, reward, terminated, truncated, info = eval_env.step(int(action))
        total_reward += reward
        steps += 1
        done = terminated or truncated

    ep_lengths.append(steps)
    ep_rewards.append(total_reward)
    if total_reward > 0:
        wins += 1
    elif total_reward < 0:
        losses += 1
    else:
        draws += 1

    if (i + 1) % 50 == 0:
        elapsed = time.time() - start
        eta = (N_GAMES - i - 1) / ((i + 1) / elapsed)
        print(f"  [{i+1}/{N_GAMES}] Win rate: {100*wins/(i+1):.1f}% | ETA: {eta:.0f}s")

eval_env.close()
elapsed = time.time() - start

# Wilson score 95% CI
wr = wins / N_GAMES
z = 1.96
d = 1 + z**2 / N_GAMES
center = (wr + z**2 / (2 * N_GAMES)) / d
spread = z * np.sqrt((wr * (1 - wr) + z**2 / (4 * N_GAMES)) / N_GAMES) / d

print(f"\n{'='*60}")
print(f"  RESULTS ({N_GAMES} games, {elapsed:.0f}s)")
print(f"  Wins: {wins} | Losses: {losses} | Draws: {draws}")
print(f"  Win rate: {100*wr:.1f}%")
print(f"  95% CI:   [{100*max(0,center-spread):.1f}%, {100*min(1,center+spread):.1f}%]")
print(f"  Avg episode length: {np.mean(ep_lengths):.0f}")
print(f"  Avg reward: {np.mean(ep_rewards):.3f}")
print(f"{'='*60}")
# Out:
# Evaluating over 500 games...
#   [50/500] Win rate: 86.0% | ETA: 36s
#   [100/500] Win rate: 85.0% | ETA: 31s
#   [150/500] Win rate: 82.0% | ETA: 27s
#   [200/500] Win rate: 83.0% | ETA: 22s
#   [250/500] Win rate: 83.2% | ETA: 19s
#   [300/500] Win rate: 83.0% | ETA: 15s
#   [350/500] Win rate: 82.9% | ETA: 11s
#   [400/500] Win rate: 83.2% | ETA: 7s
#   [450/500] Win rate: 83.8% | ETA: 4s
#   [500/500] Win rate: 84.2% | ETA: 0s
#
# ============================================================
#   RESULTS (500 games, 37s)
#   Wins: 421 | Losses: 79 | Draws: 0
#   Win rate: 84.2%
#   95% CI:   [80.7%, 87.1%]
#   Avg episode length: 296
#   Avg reward: 0.684
# ============================================================
