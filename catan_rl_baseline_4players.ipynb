# %% [markdown]
# # Catan RL Baseline — MaskablePPO
# Train a PPO agent with action masking on Catanatron, then evaluate win rate.

# %% [markdown]
# ## Cell 1: Imports & Setup

# %%
import gymnasium
import numpy as np
import time
from sb3_contrib.common.maskable.policies import MaskableActorCriticPolicy
from sb3_contrib.common.wrappers import ActionMasker
from sb3_contrib.ppo_mask import MaskablePPO
from stable_baselines3.common.callbacks import BaseCallback
import catanatron_gym
from catanatron import RandomPlayer, Color

print("Imports OK")
# Out:
# /opt/homebrew/lib/python3.11/site-packages/requests/__init__.py:113: RequestsDependencyWarning: urllib3 (2.3.0) or chardet (6.0.0dev0)/charset_normalizer (3.2.0) doesn't match a supported version!
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/pandas/core/computation/expressions.py:22: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.8.5' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# Imports OK

# %%
import torch
torch.distributions.Distribution.set_default_validate_args(False)

# %% [markdown]
# ## Cell 2: Safe Mask Function

# %%
def mask_fn(env) -> np.ndarray:
    """Safe mask — guarantees at least one valid action to prevent NaN crash."""
    valid_actions = env.unwrapped.get_valid_actions()
    mask = np.zeros(env.action_space.n, dtype=bool)
    if len(valid_actions) > 0:
        mask[valid_actions] = True
    else:
        # Fallback: allow all actions (prevents Simplex NaN error)
        mask[:] = True
    return mask

# %% [markdown]
# ## Cell 3: Logging Callback

# %%
class CatanLoggingCallback(BaseCallback):

    def __init__(self, log_freq=10_000, verbose=1):
        super().__init__(verbose)
        self.log_freq = log_freq
        self.start_time = None
        self.episode_rewards = []
        self.episode_lengths = []
        self.wins = 0
        self.losses = 0
        self.total_episodes = 0
        self._last_log_step = 0

    def _on_training_start(self):
        self.start_time = time.time()

    def _on_step(self) -> bool:
        infos = self.locals.get("infos", [])
        for info in infos:
            if "episode" in info:
                ep_reward = info["episode"]["r"]
                ep_length = info["episode"]["l"]
                self.episode_rewards.append(ep_reward)
                self.episode_lengths.append(ep_length)
                self.total_episodes += 1
                if ep_reward > 0:
                    self.wins += 1
                elif ep_reward < 0:
                    self.losses += 1

        if self.num_timesteps - self._last_log_step >= self.log_freq:
            if self.total_episodes > 0:
                self._print_stats()
            self._last_log_step = self.num_timesteps

        return True

    def _print_stats(self):
        elapsed = time.time() - self.start_time
        steps_per_sec = self.num_timesteps / elapsed
        total_steps = self.locals.get("total_timesteps", 1_000_000)
        remaining = total_steps - self.num_timesteps
        eta = remaining / steps_per_sec if steps_per_sec > 0 else 0

        recent_r = self.episode_rewards[-50:]
        recent_l = self.episode_lengths[-50:]
        recent_wins = sum(1 for r in recent_r if r > 0)

        eta_h, rem = divmod(int(eta), 3600)
        eta_m, eta_s = divmod(rem, 60)
        el_h, rem = divmod(int(elapsed), 3600)
        el_m, el_s = divmod(rem, 60)

        print(f"\n{'='*60}")
        print(f"  Step: {self.num_timesteps:,} / {total_steps:,} "
              f"({100*self.num_timesteps/total_steps:.1f}%)")
        print(f"  Elapsed: {el_h}h {el_m}m {el_s}s | "
              f"ETA: {eta_h}h {eta_m}m {eta_s}s")
        print(f"  Speed: {steps_per_sec:.0f} steps/s | "
              f"Episodes: {self.total_episodes}")
        print(f"  Overall win rate: {self.wins}/{self.total_episodes} "
              f"({100*self.wins/self.total_episodes:.1f}%)")
        print(f"  Last 50 ep: win {100*recent_wins/len(recent_r):.1f}% | "
              f"avg len {np.mean(recent_l):.0f} | "
              f"avg reward {np.mean(recent_r):.3f}")
        print(f"{'='*60}")

    def _on_training_end(self):
        elapsed = time.time() - self.start_time
        print(f"\n{'#'*60}")
        print(f"  TRAINING COMPLETE")
        print(f"  Total time: {elapsed/3600:.1f} hours")
        print(f"  Total episodes: {self.total_episodes}")
        print(f"  Final win rate: {100*self.wins/max(1,self.total_episodes):.1f}%")
        print(f"{'#'*60}")

# %% [markdown]
# ## Cell 4: Train

# %%
TOTAL_TIMESTEPS = 1_000_000
SAVE_PATH = "catan_ppo_baseline_4players"

# 1v1 against RandomPlayer
train_env = gymnasium.make(
    "catanatron-v1",
    config={
        "enemies": [
            RandomPlayer(Color.RED),
            RandomPlayer(Color.ORANGE),
            RandomPlayer(Color.WHITE),
        ],
    },
)
train_env = ActionMasker(train_env, mask_fn)

model = MaskablePPO(
    MaskableActorCriticPolicy,
    train_env,
    verbose=1,
    learning_rate=3e-4,
    n_steps=2048,
    batch_size=64,
    n_epochs=10,
    gamma=0.999,
    ent_coef=0.01,
    tensorboard_log="./catan_tb/",
    policy_kwargs=dict(net_arch=[256, 256]),
)

print(f"Obs shape: {train_env.observation_space.shape}")
print(f"Action space: {train_env.action_space.n}")
print(f"Training for {TOTAL_TIMESTEPS:,} steps...\n")

callback = CatanLoggingCallback(log_freq=10_000)
model.learn(total_timesteps=TOTAL_TIMESTEPS, callback=callback)
model.save(SAVE_PATH)
train_env.close()

print(f"\nModel saved to {SAVE_PATH}.zip")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Obs shape: (1002,)
# Action space: 290
# Training for 1,000,000 steps...
#
# Logging to ./catan_tb/PPO_6
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 253      |
# |    ep_rew_mean     | -1       |
# | time/              |          |
# |    fps             | 1972     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 259         |
# |    ep_rew_mean          | -0.733      |
# | time/                   |             |
# |    fps                  | 1222        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.016729962 |
# |    clip_fraction        | 0.161       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.631      |
# |    explained_variance   | 0.523       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0424     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0337     |
# |    value_loss           | 0.00657     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 250         |
# |    ep_rew_mean          | -0.75       |
# | time/                   |             |
# |    fps                  | 1124        |
# |    iterations           | 3           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.019139692 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.735      |
# |    explained_variance   | 0.642       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0491     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0284     |
# |    value_loss           | 0.00513     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 264        |
# |    ep_rew_mean          | -0.8       |
# | time/                   |            |
# |    fps                  | 1065       |
# |    iterations           | 4          |
# |    time_elapsed         | 7          |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.02436421 |
# |    clip_fraction        | 0.18       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.678     |
# |    explained_variance   | 0.718      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0421    |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.03      |
# |    value_loss           | 0.00328    |
# ----------------------------------------
#
# ============================================================
#   Step: 10,000 / 1,000,000 (1.0%)
#   Elapsed: 0h 0m 9s | ETA: 0h 15m 58s
#   Speed: 1033 steps/s | Episodes: 41
#   Overall win rate: 5/41 (12.2%)
#   Last 50 ep: win 12.2% | avg len 243 | avg reward -0.756
# ============================================================
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 243         |
# |    ep_rew_mean          | -0.762      |
# | time/                   |             |
# |    fps                  | 1045        |
# |    iterations           | 5           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.027752982 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.631      |
# |    explained_variance   | 0.919       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0386     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0304     |
# |    value_loss           | 0.00111     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 239        |
# |    ep_rew_mean          | -0.686     |
# | time/                   |            |
# |    fps                  | 1028       |
# |    iterations           | 6          |
# |    time_elapsed         | 11         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.02114857 |
# |    clip_fraction        | 0.174      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.669     |
# |    explained_variance   | 0.593      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0436    |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.0208    |
# |    value_loss           | 0.0041     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 240         |
# |    ep_rew_mean          | -0.593      |
# | time/                   |             |
# |    fps                  | 1013        |
# |    iterations           | 7           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.024589533 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.707      |
# |    explained_variance   | 0.413       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0423     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0241     |
# |    value_loss           | 0.00333     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 244         |
# |    ep_rew_mean          | -0.612      |
# | time/                   |             |
# |    fps                  | 1007        |
# |    iterations           | 8           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.034282215 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.721      |
# |    explained_variance   | 0.429       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0476     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0298     |
# |    value_loss           | 0.00441     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 245        |
# |    ep_rew_mean          | -0.573     |
# | time/                   |            |
# |    fps                  | 1004       |
# |    iterations           | 9          |
# |    time_elapsed         | 18         |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.03447815 |
# |    clip_fraction        | 0.223      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.667     |
# |    explained_variance   | 0.668      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0307    |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.0295    |
# |    value_loss           | 0.00213    |
# ----------------------------------------
#
# ============================================================
#   Step: 20,000 / 1,000,000 (2.0%)
#   Elapsed: 0h 0m 20s | ETA: 0h 16m 33s
#   Speed: 987 steps/s | Episodes: 82
#   Overall win rate: 18/82 (22.0%)
#   Last 50 ep: win 30.0% | avg len 227 | avg reward -0.400
# ============================================================
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 240         |
# |    ep_rew_mean          | -0.571      |
# | time/                   |             |
# |    fps                  | 1000        |
# |    iterations           | 10          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.029297031 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.717      |
# |    explained_variance   | 0.56        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0544     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0277     |
# |    value_loss           | 0.00315     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 236        |
# |    ep_rew_mean          | -0.579     |
# | time/                   |            |
# |    fps                  | 993        |
# |    iterations           | 11         |
# |    time_elapsed         | 22         |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.02965983 |
# |    clip_fraction        | 0.185      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.623     |
# |    explained_variance   | 0.523      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0198    |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.0255    |
# |    value_loss           | 0.00257    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 235         |
# |    ep_rew_mean          | -0.56       |
# | time/                   |             |
# |    fps                  | 991         |
# |    iterations           | 12          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.028409861 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.672      |
# |    explained_variance   | 0.458       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0628     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0256     |
# |    value_loss           | 0.00268     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 233         |
# |    ep_rew_mean          | -0.52       |
# | time/                   |             |
# |    fps                  | 986         |
# |    iterations           | 13          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.032468576 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.585      |
# |    explained_variance   | 0.814       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0397     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0279     |
# |    value_loss           | 0.00255     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 235        |
# |    ep_rew_mean          | -0.5       |
# | time/                   |            |
# |    fps                  | 984        |
# |    iterations           | 14         |
# |    time_elapsed         | 29         |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.04018777 |
# |    clip_fraction        | 0.204      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.623     |
# |    explained_variance   | 0.537      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0251    |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.0286    |
# |    value_loss           | 0.00465    |
# ----------------------------------------
#
# ============================================================
#   Step: 30,000 / 1,000,000 (3.0%)
#   Elapsed: 0h 0m 30s | ETA: 0h 16m 41s
#   Speed: 969 steps/s | Episodes: 128
#   Overall win rate: 32/128 (25.0%)
#   Last 50 ep: win 30.0% | avg len 214 | avg reward -0.400
# ============================================================
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 221        |
# |    ep_rew_mean          | -0.42      |
# | time/                   |            |
# |    fps                  | 981        |
# |    iterations           | 15         |
# |    time_elapsed         | 31         |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.04174009 |
# |    clip_fraction        | 0.218      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.623     |
# |    explained_variance   | 0.751      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0358    |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.0281    |
# |    value_loss           | 0.00195    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 227         |
# |    ep_rew_mean          | -0.42       |
# | time/                   |             |
# |    fps                  | 981         |
# |    iterations           | 16          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.033392355 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.558      |
# |    explained_variance   | 0.239       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0121     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0245     |
# |    value_loss           | 0.00408     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 230        |
# |    ep_rew_mean          | -0.44      |
# | time/                   |            |
# |    fps                  | 981        |
# |    iterations           | 17         |
# |    time_elapsed         | 35         |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.03252004 |
# |    clip_fraction        | 0.181      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.55      |
# |    explained_variance   | 0.763      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0298    |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.0239    |
# |    value_loss           | 0.00271    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 233         |
# |    ep_rew_mean          | -0.46       |
# | time/                   |             |
# |    fps                  | 979         |
# |    iterations           | 18          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.035870634 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.551      |
# |    explained_variance   | 0.838       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0351     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0254     |
# |    value_loss           | 0.00189     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 225         |
# |    ep_rew_mean          | -0.5        |
# | time/                   |             |
# |    fps                  | 974         |
# |    iterations           | 19          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.043721598 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.628      |
# |    explained_variance   | 0.762       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0632     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0271     |
# |    value_loss           | 0.00219     |
# -----------------------------------------
#
# ============================================================
#   Step: 40,000 / 1,000,000 (4.0%)
#   Elapsed: 0h 0m 41s | ETA: 0h 16m 39s
#   Speed: 960 steps/s | Episodes: 172
#   Overall win rate: 40/172 (23.3%)
#   Last 50 ep: win 22.0% | avg len 221 | avg reward -0.560
# ============================================================
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 225         |
# |    ep_rew_mean          | -0.52       |
# | time/                   |             |
# |    fps                  | 973         |
# |    iterations           | 20          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.032280933 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.523      |
# |    explained_variance   | 0.577       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0434     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0221     |
# |    value_loss           | 0.00424     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 226         |
# |    ep_rew_mean          | -0.52       |
# | time/                   |             |
# |    fps                  | 971         |
# |    iterations           | 21          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.038352057 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.621      |
# |    explained_variance   | 0.777       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0324     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0251     |
# |    value_loss           | 0.00215     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 232         |
# |    ep_rew_mean          | -0.56       |
# | time/                   |             |
# |    fps                  | 964         |
# |    iterations           | 22          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.033150174 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.506      |
# |    explained_variance   | 0.775       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0241     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0235     |
# |    value_loss           | 0.00211     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 228         |
# |    ep_rew_mean          | -0.48       |
# | time/                   |             |
# |    fps                  | 961         |
# |    iterations           | 23          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.043649673 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.558      |
# |    explained_variance   | 0.812       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0459     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0297     |
# |    value_loss           | 0.00292     |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 234       |
# |    ep_rew_mean          | -0.48     |
# | time/                   |           |
# |    fps                  | 959       |
# |    iterations           | 24        |
# |    time_elapsed         | 51        |
# |    total_timesteps      | 49152     |
# | train/                  |           |
# |    approx_kl            | 0.0458612 |
# |    clip_fraction        | 0.197     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.512    |
# |    explained_variance   | 0.647     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0539   |
# |    n_updates            | 230       |
# |    policy_gradient_loss | -0.0282   |
# |    value_loss           | 0.00327   |
# ---------------------------------------
#
# ============================================================
#   Step: 50,000 / 1,000,000 (5.0%)
#   Elapsed: 0h 0m 52s | ETA: 0h 16m 45s
#   Speed: 945 steps/s | Episodes: 211
#   Overall win rate: 51/211 (24.2%)
#   Last 50 ep: win 28.0% | avg len 245 | avg reward -0.440
# ============================================================
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 233         |
# |    ep_rew_mean          | -0.48       |
# | time/                   |             |
# |    fps                  | 957         |
# |    iterations           | 25          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.034543425 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.464      |
# |    explained_variance   | 0.853       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0317     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0251     |
# |    value_loss           | 0.00264     |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 237       |
# |    ep_rew_mean          | -0.54     |
# | time/                   |           |
# |    fps                  | 955       |
# |    iterations           | 26        |
# |    time_elapsed         | 55        |
# |    total_timesteps      | 53248     |
# | train/                  |           |
# |    approx_kl            | 0.0392628 |
# |    clip_fraction        | 0.187     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.491    |
# |    explained_variance   | 0.73      |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0343   |
# |    n_updates            | 250       |
# |    policy_gradient_loss | -0.0245   |
# |    value_loss           | 0.00249   |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 245         |
# |    ep_rew_mean          | -0.5        |
# | time/                   |             |
# |    fps                  | 955         |
# |    iterations           | 27          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.045221977 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.483      |
# |    explained_variance   | 0.414       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0367     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0218     |
# |    value_loss           | 0.00296     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 246        |
# |    ep_rew_mean          | -0.44      |
# | time/                   |            |
# |    fps                  | 956        |
# |    iterations           | 28         |
# |    time_elapsed         | 59         |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.03267092 |
# |    clip_fraction        | 0.187      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.518     |
# |    explained_variance   | 0.553      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0404    |
# |    n_updates            | 270        |
# |    policy_gradient_loss | -0.0202    |
# |    value_loss           | 0.00405    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 245        |
# |    ep_rew_mean          | -0.4       |
# | time/                   |            |
# |    fps                  | 957        |
# |    iterations           | 29         |
# |    time_elapsed         | 62         |
# |    total_timesteps      | 59392      |
# | train/                  |            |
# |    approx_kl            | 0.05521169 |
# |    clip_fraction        | 0.242      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.648     |
# |    explained_variance   | 0.482      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0475    |
# |    n_updates            | 280        |
# |    policy_gradient_loss | -0.0273    |
# |    value_loss           | 0.0038     |
# ----------------------------------------
#
# ============================================================
#   Step: 60,000 / 1,000,000 (6.0%)
#   Elapsed: 0h 1m 3s | ETA: 0h 16m 35s
#   Speed: 944 steps/s | Episodes: 252
#   Overall win rate: 66/252 (26.2%)
#   Last 50 ep: win 38.0% | avg len 259 | avg reward -0.240
# ============================================================
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 240        |
# |    ep_rew_mean          | -0.36      |
# | time/                   |            |
# |    fps                  | 957        |
# |    iterations           | 30         |
# |    time_elapsed         | 64         |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.04430811 |
# |    clip_fraction        | 0.204      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.56      |
# |    explained_variance   | 0.76       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0383    |
# |    n_updates            | 290        |
# |    policy_gradient_loss | -0.0228    |
# |    value_loss           | 0.00402    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 245         |
# |    ep_rew_mean          | -0.28       |
# | time/                   |             |
# |    fps                  | 957         |
# |    iterations           | 31          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.042722847 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.439      |
# |    explained_variance   | 0.849       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0405     |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0227     |
# |    value_loss           | 0.00275     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 246         |
# |    ep_rew_mean          | -0.26       |
# | time/                   |             |
# |    fps                  | 958         |
# |    iterations           | 32          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.041889027 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.529      |
# |    explained_variance   | 0.698       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0637     |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0258     |
# |    value_loss           | 0.00512     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 252         |
# |    ep_rew_mean          | -0.22       |
# | time/                   |             |
# |    fps                  | 959         |
# |    iterations           | 33          |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.062242627 |
# |    clip_fraction        | 0.221       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.556      |
# |    explained_variance   | 0.882       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0402     |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0279     |
# |    value_loss           | 0.0029      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 248         |
# |    ep_rew_mean          | -0.18       |
# | time/                   |             |
# |    fps                  | 959         |
# |    iterations           | 34          |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.046470277 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.517      |
# |    explained_variance   | 0.867       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0497     |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0278     |
# |    value_loss           | 0.00409     |
# -----------------------------------------
#
# ============================================================
#   Step: 70,000 / 1,000,000 (7.0%)
#   Elapsed: 0h 1m 13s | ETA: 0h 16m 22s
#   Speed: 947 steps/s | Episodes: 293
#   Overall win rate: 84/293 (28.7%)
#   Last 50 ep: win 42.0% | avg len 243 | avg reward -0.160
# ============================================================
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 242        |
# |    ep_rew_mean          | -0.22      |
# | time/                   |            |
# |    fps                  | 959        |
# |    iterations           | 35         |
# |    time_elapsed         | 74         |
# |    total_timesteps      | 71680      |
# | train/                  |            |
# |    approx_kl            | 0.04342194 |
# |    clip_fraction        | 0.197      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.513     |
# |    explained_variance   | 0.678      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0526    |
# |    n_updates            | 340        |
# |    policy_gradient_loss | -0.0267    |
# |    value_loss           | 0.00385    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 235         |
# |    ep_rew_mean          | -0.24       |
# | time/                   |             |
# |    fps                  | 960         |
# |    iterations           | 36          |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.045176372 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.518      |
# |    explained_variance   | 0.837       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0727     |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0261     |
# |    value_loss           | 0.00487     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 238         |
# |    ep_rew_mean          | -0.18       |
# | time/                   |             |
# |    fps                  | 960         |
# |    iterations           | 37          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.044508684 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.433      |
# |    explained_variance   | 0.826       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0615     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.027      |
# |    value_loss           | 0.0032      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 230        |
# |    ep_rew_mean          | -0.16      |
# | time/                   |            |
# |    fps                  | 960        |
# |    iterations           | 38         |
# |    time_elapsed         | 80         |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.04761469 |
# |    clip_fraction        | 0.196      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.477     |
# |    explained_variance   | 0.814      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0322    |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.0261    |
# |    value_loss           | 0.00283    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 230        |
# |    ep_rew_mean          | -0.16      |
# | time/                   |            |
# |    fps                  | 961        |
# |    iterations           | 39         |
# |    time_elapsed         | 83         |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.05542687 |
# |    clip_fraction        | 0.203      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.491     |
# |    explained_variance   | 0.788      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0299    |
# |    n_updates            | 380        |
# |    policy_gradient_loss | -0.0285    |
# |    value_loss           | 0.00384    |
# ----------------------------------------
#
# ============================================================
#   Step: 80,000 / 1,000,000 (8.0%)
#   Elapsed: 0h 1m 24s | ETA: 0h 16m 9s
#   Speed: 948 steps/s | Episodes: 340
#   Overall win rate: 103/340 (30.3%)
#   Last 50 ep: win 40.0% | avg len 212 | avg reward -0.200
# ============================================================
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 232         |
# |    ep_rew_mean          | -0.18       |
# | time/                   |             |
# |    fps                  | 962         |
# |    iterations           | 40          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.038253866 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.455      |
# |    explained_variance   | 0.451       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.036      |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.021      |
# |    value_loss           | 0.00502     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 231        |
# |    ep_rew_mean          | -0.16      |
# | time/                   |            |
# |    fps                  | 962        |
# |    iterations           | 41         |
# |    time_elapsed         | 87         |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.04138215 |
# |    clip_fraction        | 0.192      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.488     |
# |    explained_variance   | 0.751      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0203    |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.0225    |
# |    value_loss           | 0.00235    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 224         |
# |    ep_rew_mean          | -0.18       |
# | time/                   |             |
# |    fps                  | 962         |
# |    iterations           | 42          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.046839133 |
# |    clip_fraction        | 0.231       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.528      |
# |    explained_variance   | 0.678       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0488     |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0271     |
# |    value_loss           | 0.00373     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 220         |
# |    ep_rew_mean          | -0.12       |
# | time/                   |             |
# |    fps                  | 962         |
# |    iterations           | 43          |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.051888328 |
# |    clip_fraction        | 0.244       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.563      |
# |    explained_variance   | 0.761       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0424     |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0294     |
# |    value_loss           | 0.00381     |
# -----------------------------------------
#
# ============================================================
#   Step: 90,000 / 1,000,000 (9.0%)
#   Elapsed: 0h 1m 33s | ETA: 0h 15m 45s
#   Speed: 962 steps/s | Episodes: 383
#   Overall win rate: 124/383 (32.4%)
#   Last 50 ep: win 48.0% | avg len 235 | avg reward -0.040
# ============================================================
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 224         |
# |    ep_rew_mean          | -0.14       |
# | time/                   |             |
# |    fps                  | 962         |
# |    iterations           | 44          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.056448445 |
# |    clip_fraction        | 0.208       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.481      |
# |    explained_variance   | 0.942       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0594     |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0298     |
# |    value_loss           | 0.00232     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 220         |
# |    ep_rew_mean          | -0.1        |
# | time/                   |             |
# |    fps                  | 962         |
# |    iterations           | 45          |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.042408906 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.543      |
# |    explained_variance   | 0.832       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0351     |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0203     |
# |    value_loss           | 0.0103      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 230        |
# |    ep_rew_mean          | -0.04      |
# | time/                   |            |
# |    fps                  | 963        |
# |    iterations           | 46         |
# |    time_elapsed         | 97         |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.05107429 |
# |    clip_fraction        | 0.21       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.511     |
# |    explained_variance   | 0.901      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0331    |
# |    n_updates            | 450        |
# |    policy_gradient_loss | -0.0253    |
# |    value_loss           | 0.00374    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 236         |
# |    ep_rew_mean          | -0.1        |
# | time/                   |             |
# |    fps                  | 963         |
# |    iterations           | 47          |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.058711812 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.438      |
# |    explained_variance   | 0.833       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0548     |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0272     |
# |    value_loss           | 0.00249     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 230         |
# |    ep_rew_mean          | -0.12       |
# | time/                   |             |
# |    fps                  | 963         |
# |    iterations           | 48          |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.044070505 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.422      |
# |    explained_variance   | 0.616       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0476     |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0239     |
# |    value_loss           | 0.0039      |
# -----------------------------------------
#
# ============================================================
#   Step: 100,000 / 1,000,000 (10.0%)
#   Elapsed: 0h 1m 43s | ETA: 0h 15m 35s
#   Speed: 962 steps/s | Episodes: 426
#   Overall win rate: 140/426 (32.9%)
#   Last 50 ep: win 38.0% | avg len 230 | avg reward -0.240
# ============================================================
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 230         |
# |    ep_rew_mean          | -0.14       |
# | time/                   |             |
# |    fps                  | 963         |
# |    iterations           | 49          |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.050531533 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.39       |
# |    explained_variance   | 0.841       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0442     |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0259     |
# |    value_loss           | 0.00214     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 232         |
# |    ep_rew_mean          | -0.14       |
# | time/                   |             |
# |    fps                  | 964         |
# |    iterations           | 50          |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.057559945 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.389      |
# |    explained_variance   | 0.752       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0392     |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0222     |
# |    value_loss           | 0.00258     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 235         |
# |    ep_rew_mean          | -0.2        |
# | time/                   |             |
# |    fps                  | 963         |
# |    iterations           | 51          |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.047544368 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.404      |
# |    explained_variance   | 0.77        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0372     |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0254     |
# |    value_loss           | 0.00383     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 234         |
# |    ep_rew_mean          | -0.18       |
# | time/                   |             |
# |    fps                  | 964         |
# |    iterations           | 52          |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.042285487 |
# |    clip_fraction        | 0.183       |
# ...
# |    approx_kl            | 0.06087755 |
# |    clip_fraction        | 0.174      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.301     |
# |    explained_variance   | 0.834      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0406    |
# |    n_updates            | 4720       |
# |    policy_gradient_loss | -0.0238    |
# |    value_loss           | 0.0043     |
# ----------------------------------------
#
# ============================================================
#   Step: 970,000 / 1,000,000 (97.0%)
#   Elapsed: 0h 17m 6s | ETA: 0h 0m 31s
#   Speed: 945 steps/s | Episodes: 4651
#   Overall win rate: 2797/4651 (60.1%)
#   Last 50 ep: win 60.0% | avg len 206 | avg reward 0.200
# ============================================================
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 201         |
# |    ep_rew_mean          | 0.28        |
# | time/                   |             |
# |    fps                  | 945         |
# |    iterations           | 474         |
# |    time_elapsed         | 1027        |
# |    total_timesteps      | 970752      |
# | train/                  |             |
# |    approx_kl            | 0.077243395 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.276      |
# |    explained_variance   | 0.913       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0352     |
# |    n_updates            | 4730        |
# |    policy_gradient_loss | -0.027      |
# |    value_loss           | 0.00292     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 206        |
# |    ep_rew_mean          | 0.16       |
# | time/                   |            |
# |    fps                  | 945        |
# |    iterations           | 475        |
# |    time_elapsed         | 1029       |
# |    total_timesteps      | 972800     |
# | train/                  |            |
# |    approx_kl            | 0.08213193 |
# |    clip_fraction        | 0.185      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.307     |
# |    explained_variance   | 0.862      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0116    |
# |    n_updates            | 4740       |
# |    policy_gradient_loss | -0.0284    |
# |    value_loss           | 0.00257    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 203         |
# |    ep_rew_mean          | 0.18        |
# | time/                   |             |
# |    fps                  | 945         |
# |    iterations           | 476         |
# |    time_elapsed         | 1031        |
# |    total_timesteps      | 974848      |
# | train/                  |             |
# |    approx_kl            | 0.059867702 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.306      |
# |    explained_variance   | 0.654       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0629     |
# |    n_updates            | 4750        |
# |    policy_gradient_loss | -0.0203     |
# |    value_loss           | 0.00556     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 202        |
# |    ep_rew_mean          | 0.3        |
# | time/                   |            |
# |    fps                  | 945        |
# |    iterations           | 477        |
# |    time_elapsed         | 1033       |
# |    total_timesteps      | 976896     |
# | train/                  |            |
# |    approx_kl            | 0.07413666 |
# |    clip_fraction        | 0.166      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.263     |
# |    explained_variance   | 0.945      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0312    |
# |    n_updates            | 4760       |
# |    policy_gradient_loss | -0.0264    |
# |    value_loss           | 0.00228    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 195        |
# |    ep_rew_mean          | 0.32       |
# | time/                   |            |
# |    fps                  | 944        |
# |    iterations           | 478        |
# |    time_elapsed         | 1035       |
# |    total_timesteps      | 978944     |
# | train/                  |            |
# |    approx_kl            | 0.08426436 |
# |    clip_fraction        | 0.145      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.231     |
# |    explained_variance   | 0.799      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0329    |
# |    n_updates            | 4770       |
# |    policy_gradient_loss | -0.0227    |
# |    value_loss           | 0.00171    |
# ----------------------------------------
#
# ============================================================
#   Step: 980,000 / 1,000,000 (98.0%)
#   Elapsed: 0h 17m 17s | ETA: 0h 0m 21s
#   Speed: 944 steps/s | Episodes: 4705
#   Overall win rate: 2834/4705 (60.2%)
#   Last 50 ep: win 70.0% | avg len 183 | avg reward 0.400
# ============================================================
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 194        |
# |    ep_rew_mean          | 0.32       |
# | time/                   |            |
# |    fps                  | 945        |
# |    iterations           | 479        |
# |    time_elapsed         | 1038       |
# |    total_timesteps      | 980992     |
# | train/                  |            |
# |    approx_kl            | 0.05277941 |
# |    clip_fraction        | 0.152      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.268     |
# |    explained_variance   | 0.702      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0332    |
# |    n_updates            | 4780       |
# |    policy_gradient_loss | -0.0232    |
# |    value_loss           | 0.00588    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 191        |
# |    ep_rew_mean          | 0.3        |
# | time/                   |            |
# |    fps                  | 945        |
# |    iterations           | 480        |
# |    time_elapsed         | 1040       |
# |    total_timesteps      | 983040     |
# | train/                  |            |
# |    approx_kl            | 0.07288345 |
# |    clip_fraction        | 0.177      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.285     |
# |    explained_variance   | 0.943      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0437    |
# |    n_updates            | 4790       |
# |    policy_gradient_loss | -0.0303    |
# |    value_loss           | 0.00213    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 192         |
# |    ep_rew_mean          | 0.34        |
# | time/                   |             |
# |    fps                  | 945         |
# |    iterations           | 481         |
# |    time_elapsed         | 1042        |
# |    total_timesteps      | 985088      |
# | train/                  |             |
# |    approx_kl            | 0.058597285 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.269      |
# |    explained_variance   | 0.918       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.03       |
# |    n_updates            | 4800        |
# |    policy_gradient_loss | -0.0233     |
# |    value_loss           | 0.00251     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 198         |
# |    ep_rew_mean          | 0.32        |
# | time/                   |             |
# |    fps                  | 945         |
# |    iterations           | 482         |
# |    time_elapsed         | 1044        |
# |    total_timesteps      | 987136      |
# | train/                  |             |
# |    approx_kl            | 0.051384617 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.191      |
# |    explained_variance   | 0.938       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0495     |
# |    n_updates            | 4810        |
# |    policy_gradient_loss | -0.0209     |
# |    value_loss           | 0.00205     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 193         |
# |    ep_rew_mean          | 0.36        |
# | time/                   |             |
# |    fps                  | 945         |
# |    iterations           | 483         |
# |    time_elapsed         | 1046        |
# |    total_timesteps      | 989184      |
# | train/                  |             |
# |    approx_kl            | 0.041845575 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.247      |
# |    explained_variance   | 0.969       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0306     |
# |    n_updates            | 4820        |
# |    policy_gradient_loss | -0.0229     |
# |    value_loss           | 0.00182     |
# -----------------------------------------
#
# ============================================================
#   Step: 990,000 / 1,000,000 (99.0%)
#   Elapsed: 0h 17m 28s | ETA: 0h 0m 10s
#   Speed: 944 steps/s | Episodes: 4755
#   Overall win rate: 2866/4755 (60.3%)
#   Last 50 ep: win 64.0% | avg len 201 | avg reward 0.280
# ============================================================
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 195         |
# |    ep_rew_mean          | 0.34        |
# | time/                   |             |
# |    fps                  | 945         |
# |    iterations           | 484         |
# |    time_elapsed         | 1048        |
# |    total_timesteps      | 991232      |
# | train/                  |             |
# |    approx_kl            | 0.047486678 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.223      |
# |    explained_variance   | 0.683       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.018      |
# |    n_updates            | 4830        |
# |    policy_gradient_loss | -0.0216     |
# |    value_loss           | 0.00434     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 196        |
# |    ep_rew_mean          | 0.38       |
# | time/                   |            |
# |    fps                  | 945        |
# |    iterations           | 485        |
# |    time_elapsed         | 1050       |
# |    total_timesteps      | 993280     |
# | train/                  |            |
# |    approx_kl            | 0.05951778 |
# |    clip_fraction        | 0.138      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.233     |
# |    explained_variance   | 0.933      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0514    |
# |    n_updates            | 4840       |
# |    policy_gradient_loss | -0.0201    |
# |    value_loss           | 0.00306    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 191         |
# |    ep_rew_mean          | 0.36        |
# | time/                   |             |
# |    fps                  | 945         |
# |    iterations           | 486         |
# |    time_elapsed         | 1053        |
# |    total_timesteps      | 995328      |
# | train/                  |             |
# |    approx_kl            | 0.053501524 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.237      |
# |    explained_variance   | 0.88        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.024      |
# |    n_updates            | 4850        |
# |    policy_gradient_loss | -0.0225     |
# |    value_loss           | 0.00256     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 190         |
# |    ep_rew_mean          | 0.4         |
# | time/                   |             |
# |    fps                  | 945         |
# |    iterations           | 487         |
# |    time_elapsed         | 1055        |
# |    total_timesteps      | 997376      |
# | train/                  |             |
# |    approx_kl            | 0.061669707 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.234      |
# |    explained_variance   | 0.674       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00796    |
# |    n_updates            | 4860        |
# |    policy_gradient_loss | -0.0199     |
# |    value_loss           | 0.00476     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 188        |
# |    ep_rew_mean          | 0.4        |
# | time/                   |            |
# |    fps                  | 945        |
# |    iterations           | 488        |
# |    time_elapsed         | 1057       |
# |    total_timesteps      | 999424     |
# | train/                  |            |
# |    approx_kl            | 0.04551418 |
# |    clip_fraction        | 0.11       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.187     |
# |    explained_variance   | 0.614      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0237    |
# |    n_updates            | 4870       |
# |    policy_gradient_loss | -0.0149    |
# |    value_loss           | 0.00222    |
# ----------------------------------------
#
# ============================================================
#   Step: 1,000,000 / 1,000,000 (100.0%)
#   Elapsed: 0h 17m 38s | ETA: 0h 0m 0s
#   Speed: 944 steps/s | Episodes: 4809
#   Overall win rate: 2906/4809 (60.4%)
#   Last 50 ep: win 76.0% | avg len 173 | avg reward 0.520
# ============================================================
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 194        |
# |    ep_rew_mean          | 0.36       |
# | time/                   |            |
# |    fps                  | 945        |
# |    iterations           | 489        |
# |    time_elapsed         | 1059       |
# |    total_timesteps      | 1001472    |
# | train/                  |            |
# |    approx_kl            | 0.06470848 |
# |    clip_fraction        | 0.151      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.255     |
# |    explained_variance   | 0.812      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.037     |
# |    n_updates            | 4880       |
# |    policy_gradient_loss | -0.0227    |
# |    value_loss           | 0.0039     |
# ----------------------------------------
#
# ############################################################
#   TRAINING COMPLETE
#   Total time: 0.3 hours
#   Total episodes: 4817
#   Final win rate: 60.5%
# ############################################################
#
# Model saved to catan_ppo_baseline_4players.zip

# %%
import matplotlib.pyplot as plt

rewards = callback.episode_rewards
lengths = callback.episode_lengths

window = 50

if len(rewards) >= window:
    smoothed = np.convolve(rewards, np.ones(window)/window, mode='valid')
    smoothed_len = np.convolve(lengths, np.ones(window)/window, mode='valid')
    wins_binary = [1 if r > 0 else 0 for r in rewards]
    win_rate = np.convolve(wins_binary, np.ones(window)/window, mode='valid')

    fig, axes = plt.subplots(1, 3, figsize=(18, 5))

    axes[0].plot(smoothed)
    axes[0].set_title("Episode Reward (50-ep rolling avg)")
    axes[0].set_xlabel("Episode")
    axes[0].set_ylabel("Reward")
    axes[0].axhline(y=0, color='gray', linestyle='--', alpha=0.5)

    axes[1].plot(smoothed_len)
    axes[1].set_title("Episode Length (50-ep rolling avg)")
    axes[1].set_xlabel("Episode")
    axes[1].set_ylabel("Steps")

    axes[2].plot(100 * win_rate)
    axes[2].set_title("Win Rate (50-ep rolling avg)")
    axes[2].set_xlabel("Episode")
    axes[2].set_ylabel("Win Rate %")
    axes[2].axhline(y=50, color='red', linestyle='--', alpha=0.5, label='50%')
    axes[2].legend()

    plt.tight_layout()
    plt.show()

    print(f"Total episodes: {len(rewards)}")
    print(f"Final 50-ep win rate: {100*win_rate[-1]:.1f}%")
    print(f"Final 50-ep avg reward: {smoothed[-1]:.3f}")
else:
    print(f"Only {len(rewards)} episodes, need {window} to plot")
# Out:
# Total episodes: 4817
# Final 50-ep win rate: 78.0%
# Final 50-ep avg reward: 0.560

# %% [markdown]
# ## Cell 5: Evaluate

# %%
SAVE_PATH = "catan_ppo_baseline_4players"  # must match training
N_GAMES = 500

model = MaskablePPO.load(SAVE_PATH)

eval_env = gymnasium.make(
    "catanatron-v1",
    config={
    "enemies": [
        RandomPlayer(Color.RED),
        RandomPlayer(Color.ORANGE),
        RandomPlayer(Color.WHITE),
    ],
},
)

wins, losses, draws = 0, 0, 0
ep_lengths = []
ep_rewards = []

print(f"Evaluating over {N_GAMES} games...")
start = time.time()

for i in range(N_GAMES):
    obs, info = eval_env.reset()
    done = False
    total_reward = 0
    steps = 0

    while not done:
        valid = eval_env.unwrapped.get_valid_actions()
        mask = np.zeros(eval_env.action_space.n, dtype=bool)
        if len(valid) > 0:
            mask[valid] = True
        else:
            mask[:] = True

        action, _ = model.predict(obs, action_masks=mask, deterministic=True)
        obs, reward, terminated, truncated, info = eval_env.step(int(action))
        total_reward += reward
        steps += 1
        done = terminated or truncated

    ep_lengths.append(steps)
    ep_rewards.append(total_reward)
    if total_reward > 0:
        wins += 1
    elif total_reward < 0:
        losses += 1
    else:
        draws += 1

    if (i + 1) % 50 == 0:
        elapsed = time.time() - start
        eta = (N_GAMES - i - 1) / ((i + 1) / elapsed)
        print(f"  [{i+1}/{N_GAMES}] Win rate: {100*wins/(i+1):.1f}% | ETA: {eta:.0f}s")

eval_env.close()
elapsed = time.time() - start

# Wilson score 95% CI
wr = wins / N_GAMES
z = 1.96
d = 1 + z**2 / N_GAMES
center = (wr + z**2 / (2 * N_GAMES)) / d
spread = z * np.sqrt((wr * (1 - wr) + z**2 / (4 * N_GAMES)) / N_GAMES) / d

print(f"\n{'='*60}")
print(f"  RESULTS ({N_GAMES} games, {elapsed:.0f}s)")
print(f"  Wins: {wins} | Losses: {losses} | Draws: {draws}")
print(f"  Win rate: {100*wr:.1f}%")
print(f"  95% CI:   [{100*max(0,center-spread):.1f}%, {100*min(1,center+spread):.1f}%]")
print(f"  Avg episode length: {np.mean(ep_lengths):.0f}")
print(f"  Avg reward: {np.mean(ep_rewards):.3f}")
print(f"{'='*60}")
# Out:
# Evaluating over 500 games...
#   [50/500] Win rate: 74.0% | ETA: 30s
#   [100/500] Win rate: 76.0% | ETA: 27s
#   [150/500] Win rate: 71.3% | ETA: 24s
#   [200/500] Win rate: 70.5% | ETA: 20s
#   [250/500] Win rate: 72.0% | ETA: 17s
#   [300/500] Win rate: 72.0% | ETA: 13s
#   [350/500] Win rate: 71.7% | ETA: 10s
#   [400/500] Win rate: 71.8% | ETA: 7s
#   [450/500] Win rate: 71.1% | ETA: 3s
#   [500/500] Win rate: 70.8% | ETA: 0s
#
# ============================================================
#   RESULTS (500 games, 34s)
#   Wins: 354 | Losses: 146 | Draws: 0
#   Win rate: 70.8%
#   95% CI:   [66.7%, 74.6%]
#   Avg episode length: 191
#   Avg reward: 0.416
# ============================================================
