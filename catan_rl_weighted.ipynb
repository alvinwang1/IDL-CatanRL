# %% [markdown]
# # Catan RL — PPO vs WeightedRandomPlayer
# Second baseline experiment: harder opponent that prefers cities > settlements > dev cards.

# %%
import gymnasium
import numpy as np
import time
import torch
torch.distributions.Distribution.set_default_validate_args(False)

from sb3_contrib.common.maskable.policies import MaskableActorCriticPolicy
from sb3_contrib.common.wrappers import ActionMasker
from sb3_contrib.ppo_mask import MaskablePPO
from stable_baselines3.common.callbacks import BaseCallback
import catanatron_gym
from catanatron import Color
from catanatron.players.weighted_random import WeightedRandomPlayer

print("Imports OK")
# Out:
# /opt/homebrew/lib/python3.11/site-packages/requests/__init__.py:113: RequestsDependencyWarning: urllib3 (2.3.0) or chardet (6.0.0dev0)/charset_normalizer (3.2.0) doesn't match a supported version!
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/pandas/core/computation/expressions.py:22: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.8.5' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# Imports OK

# %%
def mask_fn(env) -> np.ndarray:
    valid_actions = env.unwrapped.get_valid_actions()
    mask = np.zeros(env.action_space.n, dtype=bool)
    if len(valid_actions) > 0:
        mask[valid_actions] = True
    else:
        mask[:] = True
    return mask


class CatanLoggingCallback(BaseCallback):

    def __init__(self, log_freq=10_000, verbose=1):
        super().__init__(verbose)
        self.log_freq = log_freq
        self.start_time = None
        self.episode_rewards = []
        self.episode_lengths = []
        self.wins = 0
        self.losses = 0
        self.total_episodes = 0
        self._last_log_step = 0

    def _on_training_start(self):
        self.start_time = time.time()

    def _on_step(self) -> bool:
        infos = self.locals.get("infos", [])
        for info in infos:
            if "episode" in info:
                ep_reward = info["episode"]["r"]
                ep_length = info["episode"]["l"]
                self.episode_rewards.append(ep_reward)
                self.episode_lengths.append(ep_length)
                self.total_episodes += 1
                if ep_reward > 0:
                    self.wins += 1
                elif ep_reward < 0:
                    self.losses += 1

        if self.num_timesteps - self._last_log_step >= self.log_freq:
            if self.total_episodes > 0:
                self._print_stats()
            self._last_log_step = self.num_timesteps

        return True

    def _print_stats(self):
        elapsed = time.time() - self.start_time
        steps_per_sec = self.num_timesteps / elapsed
        total_steps = self.locals.get("total_timesteps", 1_000_000)
        remaining = total_steps - self.num_timesteps
        eta = remaining / steps_per_sec if steps_per_sec > 0 else 0

        recent_r = self.episode_rewards[-50:]
        recent_l = self.episode_lengths[-50:]
        recent_wins = sum(1 for r in recent_r if r > 0)

        eta_h, rem = divmod(int(eta), 3600)
        eta_m, eta_s = divmod(rem, 60)
        el_h, rem = divmod(int(elapsed), 3600)
        el_m, el_s = divmod(rem, 60)

        print(f"\n{'='*60}")
        print(f"  Step: {self.num_timesteps:,} / {total_steps:,} "
              f"({100*self.num_timesteps/total_steps:.1f}%)")
        print(f"  Elapsed: {el_h}h {el_m}m {el_s}s | "
              f"ETA: {eta_h}h {eta_m}m {eta_s}s")
        print(f"  Speed: {steps_per_sec:.0f} steps/s | "
              f"Episodes: {self.total_episodes}")
        print(f"  Overall win rate: {self.wins}/{self.total_episodes} "
              f"({100*self.wins/self.total_episodes:.1f}%)")
        print(f"  Last 50 ep: win {100*recent_wins/len(recent_r):.1f}% | "
              f"avg len {np.mean(recent_l):.0f} | "
              f"avg reward {np.mean(recent_r):.3f}")
        print(f"{'='*60}")

    def _on_training_end(self):
        elapsed = time.time() - self.start_time
        print(f"\n{'#'*60}")
        print(f"  TRAINING COMPLETE")
        print(f"  Total time: {elapsed/3600:.1f} hours")
        print(f"  Total episodes: {self.total_episodes}")
        print(f"  Final win rate: {100*self.wins/max(1,self.total_episodes):.1f}%")
        print(f"{'#'*60}")

# %%
TOTAL_TIMESTEPS = 1_000_000
SAVE_PATH = "catan_ppo_vs_weighted"

train_env = gymnasium.make(
    "catanatron-v1",
    config={"enemies": [WeightedRandomPlayer(Color.RED)]},
)
train_env = ActionMasker(train_env, mask_fn)

model = MaskablePPO(
    MaskableActorCriticPolicy,
    train_env,
    verbose=1,
    learning_rate=3e-4,
    n_steps=2048,
    batch_size=64,
    n_epochs=10,
    gamma=0.999,
    ent_coef=0.01,
    tensorboard_log="./catan_tb_weighted/",
    policy_kwargs=dict(net_arch=[256, 256]),
)

print(f"Obs shape: {train_env.observation_space.shape}")
print(f"Action space: {train_env.action_space.n}")
print(f"Training for {TOTAL_TIMESTEPS:,} steps vs WeightedRandomPlayer...\n")

callback = CatanLoggingCallback(log_freq=10_000)
model.learn(total_timesteps=TOTAL_TIMESTEPS, callback=callback)
model.save(SAVE_PATH)
train_env.close()

print(f"\nModel saved to {SAVE_PATH}.zip")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Obs shape: (614,)
# Action space: 290
# Training for 1,000,000 steps vs WeightedRandomPlayer...
#
# Logging to ./catan_tb_weighted/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 260      |
# |    ep_rew_mean     | -0.429   |
# | time/              |          |
# |    fps             | 3168     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 381         |
# |    ep_rew_mean          | -0.4        |
# | time/                   |             |
# |    fps                  | 1698        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.012515854 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.524      |
# |    explained_variance   | 0.344       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0443     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0226     |
# |    value_loss           | 0.00585     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 404         |
# |    ep_rew_mean          | -0.333      |
# | time/                   |             |
# |    fps                  | 1468        |
# |    iterations           | 3           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.014388949 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.446      |
# |    explained_variance   | 0.699       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0311     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0163     |
# |    value_loss           | 0.00319     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 382         |
# |    ep_rew_mean          | -0.333      |
# | time/                   |             |
# |    fps                  | 1364        |
# |    iterations           | 4           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.017474685 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.492      |
# |    explained_variance   | 0.706       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00823    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0174     |
# |    value_loss           | 0.00373     |
# -----------------------------------------
#
# ============================================================
#   Step: 10,000 / 1,000,000 (1.0%)
#   Elapsed: 0h 0m 7s | ETA: 0h 12m 55s
#   Speed: 1277 steps/s | Episodes: 24
#   Overall win rate: 8/24 (33.3%)
#   Last 50 ep: win 33.3% | avg len 388 | avg reward -0.333
# ============================================================
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 406         |
# |    ep_rew_mean          | -0.36       |
# | time/                   |             |
# |    fps                  | 1292        |
# |    iterations           | 5           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.017722158 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.512      |
# |    explained_variance   | 0.682       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.022      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0173     |
# |    value_loss           | 0.00334     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 392         |
# |    ep_rew_mean          | -0.355      |
# | time/                   |             |
# |    fps                  | 1252        |
# |    iterations           | 6           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.016011639 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.414      |
# |    explained_variance   | 0.872       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0427     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0128     |
# |    value_loss           | 0.00378     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 405         |
# |    ep_rew_mean          | -0.353      |
# | time/                   |             |
# |    fps                  | 1224        |
# |    iterations           | 7           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.014995251 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.434      |
# |    explained_variance   | 0.443       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0134     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0125     |
# |    value_loss           | 0.00368     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 427         |
# |    ep_rew_mean          | -0.316      |
# | time/                   |             |
# |    fps                  | 1205        |
# |    iterations           | 8           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.018549595 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.399      |
# |    explained_variance   | 0.975       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0188     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0144     |
# |    value_loss           | 0.00182     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 427         |
# |    ep_rew_mean          | -0.302      |
# | time/                   |             |
# |    fps                  | 1192        |
# |    iterations           | 9           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.019150399 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.426      |
# |    explained_variance   | 0.879       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0307     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0137     |
# |    value_loss           | 0.0031      |
# -----------------------------------------
#
# ============================================================
#   Step: 20,000 / 1,000,000 (2.0%)
#   Elapsed: 0h 0m 17s | ETA: 0h 14m 0s
#   Speed: 1166 steps/s | Episodes: 45
#   Overall win rate: 17/45 (37.8%)
#   Last 50 ep: win 37.8% | avg len 428 | avg reward -0.244
# ============================================================
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 435         |
# |    ep_rew_mean          | -0.217      |
# | time/                   |             |
# |    fps                  | 1183        |
# |    iterations           | 10          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.017962324 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.463      |
# |    explained_variance   | 0.691       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0102     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0105     |
# |    value_loss           | 0.00525     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 450         |
# |    ep_rew_mean          | -0.24       |
# | time/                   |             |
# |    fps                  | 1171        |
# |    iterations           | 11          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.025908554 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.452      |
# |    explained_variance   | 0.933       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0411     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0178     |
# |    value_loss           | 0.00204     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 433         |
# |    ep_rew_mean          | -0.286      |
# | time/                   |             |
# |    fps                  | 1157        |
# |    iterations           | 12          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.019302562 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.44       |
# |    explained_variance   | 0.555       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00966    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0144     |
# |    value_loss           | 0.00471     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 415         |
# |    ep_rew_mean          | -0.344      |
# | time/                   |             |
# |    fps                  | 1142        |
# |    iterations           | 13          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.019136038 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.371      |
# |    explained_variance   | 0.688       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0236     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0128     |
# |    value_loss           | 0.0021      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 415         |
# |    ep_rew_mean          | -0.304      |
# | time/                   |             |
# |    fps                  | 1136        |
# |    iterations           | 14          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.019336563 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.402      |
# |    explained_variance   | -0.0669     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00719    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0126     |
# |    value_loss           | 0.00956     |
# -----------------------------------------
#
# ============================================================
#   Step: 30,000 / 1,000,000 (3.0%)
#   Elapsed: 0h 0m 26s | ETA: 0h 14m 31s
#   Speed: 1113 steps/s | Episodes: 74
#   Overall win rate: 25/74 (33.8%)
#   Last 50 ep: win 34.0% | avg len 410 | avg reward -0.320
# ============================================================
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 396         |
# |    ep_rew_mean          | -0.325      |
# | time/                   |             |
# |    fps                  | 1129        |
# |    iterations           | 15          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.023237377 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.431      |
# |    explained_variance   | 0.43        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0381     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0138     |
# |    value_loss           | 0.00353     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 407         |
# |    ep_rew_mean          | -0.325      |
# | time/                   |             |
# |    fps                  | 1129        |
# |    iterations           | 16          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.025270484 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.441      |
# |    explained_variance   | 0.834       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0176     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0165     |
# |    value_loss           | 0.00208     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 402         |
# |    ep_rew_mean          | -0.349      |
# | time/                   |             |
# |    fps                  | 1130        |
# |    iterations           | 17          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.021019988 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.357      |
# |    explained_variance   | 0.847       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0119     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.011      |
# |    value_loss           | 0.00156     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 403         |
# |    ep_rew_mean          | -0.326      |
# | time/                   |             |
# |    fps                  | 1130        |
# |    iterations           | 18          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.026024297 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.446      |
# |    explained_variance   | 0.802       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0203     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0145     |
# |    value_loss           | 0.00155     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 410         |
# |    ep_rew_mean          | -0.305      |
# | time/                   |             |
# |    fps                  | 1131        |
# |    iterations           | 19          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.023012105 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.361      |
# |    explained_variance   | 0.924       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0466     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0136     |
# |    value_loss           | 0.00142     |
# -----------------------------------------
#
# ============================================================
#   Step: 40,000 / 1,000,000 (4.0%)
#   Elapsed: 0h 0m 35s | ETA: 0h 14m 21s
#   Speed: 1115 steps/s | Episodes: 97
#   Overall win rate: 34/97 (35.1%)
#   Last 50 ep: win 32.0% | avg len 385 | avg reward -0.360
# ============================================================
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 413         |
# |    ep_rew_mean          | -0.313      |
# | time/                   |             |
# |    fps                  | 1128        |
# |    iterations           | 20          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.021668082 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.382      |
# |    explained_variance   | 0.808       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0081     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0131     |
# |    value_loss           | 0.00222     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 417         |
# |    ep_rew_mean          | -0.32       |
# | time/                   |             |
# |    fps                  | 1125        |
# |    iterations           | 21          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.018633496 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.369      |
# |    explained_variance   | 0.808       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0238     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0129     |
# |    value_loss           | 0.00136     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 412         |
# |    ep_rew_mean          | -0.26       |
# | time/                   |             |
# |    fps                  | 1119        |
# |    iterations           | 22          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.025830615 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.37       |
# |    explained_variance   | 0.862       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00786    |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0148     |
# |    value_loss           | 0.00129     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 408         |
# |    ep_rew_mean          | -0.28       |
# | time/                   |             |
# |    fps                  | 1118        |
# |    iterations           | 23          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.035624787 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.451      |
# |    explained_variance   | 0.864       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0256     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.017      |
# |    value_loss           | 0.00269     |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 410       |
# |    ep_rew_mean          | -0.28     |
# | time/                   |           |
# |    fps                  | 1118      |
# |    iterations           | 24        |
# |    time_elapsed         | 43        |
# |    total_timesteps      | 49152     |
# | train/                  |           |
# |    approx_kl            | 0.0232203 |
# |    clip_fraction        | 0.133     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.418    |
# |    explained_variance   | 0.802     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0216   |
# |    n_updates            | 230       |
# |    policy_gradient_loss | -0.013    |
# |    value_loss           | 0.00138   |
# ---------------------------------------
#
# ============================================================
#   Step: 50,000 / 1,000,000 (5.0%)
#   Elapsed: 0h 0m 45s | ETA: 0h 14m 22s
#   Speed: 1102 steps/s | Episodes: 122
#   Overall win rate: 44/122 (36.1%)
#   Last 50 ep: win 38.0% | avg len 409 | avg reward -0.240
# ============================================================
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 418         |
# |    ep_rew_mean          | -0.28       |
# | time/                   |             |
# |    fps                  | 1118        |
# |    iterations           | 25          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.026270699 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.425      |
# |    explained_variance   | 0.762       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0225     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0144     |
# |    value_loss           | 0.00336     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 415         |
# |    ep_rew_mean          | -0.22       |
# | time/                   |             |
# |    fps                  | 1119        |
# |    iterations           | 26          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.018347377 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.333      |
# |    explained_variance   | 0.721       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0135     |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0116     |
# |    value_loss           | 0.00149     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 404        |
# |    ep_rew_mean          | -0.26      |
# | time/                   |            |
# |    fps                  | 1119       |
# |    iterations           | 27         |
# |    time_elapsed         | 49         |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.02644799 |
# |    clip_fraction        | 0.148      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.415     |
# |    explained_variance   | 0.749      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0207    |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.016     |
# |    value_loss           | 0.00317    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 395        |
# |    ep_rew_mean          | -0.2       |
# | time/                   |            |
# |    fps                  | 1114       |
# |    iterations           | 28         |
# |    time_elapsed         | 51         |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.03024935 |
# |    clip_fraction        | 0.133      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.397     |
# |    explained_variance   | 0.855      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0186    |
# |    n_updates            | 270        |
# |    policy_gradient_loss | -0.0163    |
# |    value_loss           | 0.00804    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 379         |
# |    ep_rew_mean          | -0.28       |
# | time/                   |             |
# |    fps                  | 1114        |
# |    iterations           | 29          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.039560795 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.4        |
# |    explained_variance   | 0.898       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0403     |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0196     |
# |    value_loss           | 0.00192     |
# -----------------------------------------
#
# ============================================================
#   Step: 60,000 / 1,000,000 (6.0%)
#   Elapsed: 0h 0m 54s | ETA: 0h 14m 16s
#   Speed: 1098 steps/s | Episodes: 150
#   Overall win rate: 55/150 (36.7%)
#   Last 50 ep: win 42.0% | avg len 367 | avg reward -0.160
# ============================================================
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 375         |
# |    ep_rew_mean          | -0.28       |
# | time/                   |             |
# |    fps                  | 1113        |
# |    iterations           | 30          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.030962564 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.445      |
# |    explained_variance   | 0.568       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0115     |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0167     |
# |    value_loss           | 0.00292     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 384        |
# |    ep_rew_mean          | -0.22      |
# | time/                   |            |
# |    fps                  | 1110       |
# |    iterations           | 31         |
# |    time_elapsed         | 57         |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.03530474 |
# |    clip_fraction        | 0.16       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.42      |
# |    explained_variance   | 0.87       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0247    |
# |    n_updates            | 300        |
# |    policy_gradient_loss | -0.0177    |
# |    value_loss           | 0.00116    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 383         |
# |    ep_rew_mean          | -0.2        |
# | time/                   |             |
# |    fps                  | 1106        |
# |    iterations           | 32          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.029609902 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.497      |
# |    explained_variance   | 0.618       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0359     |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0195     |
# |    value_loss           | 0.00204     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 384         |
# |    ep_rew_mean          | -0.2        |
# | time/                   |             |
# |    fps                  | 1106        |
# |    iterations           | 33          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.021983236 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.42       |
# |    explained_variance   | 0.849       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0129     |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0163     |
# |    value_loss           | 0.00219     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 393        |
# |    ep_rew_mean          | -0.2       |
# | time/                   |            |
# |    fps                  | 1107       |
# |    iterations           | 34         |
# |    time_elapsed         | 62         |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.03527677 |
# |    clip_fraction        | 0.144      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.405     |
# |    explained_variance   | 0.937      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00117    |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.0164    |
# |    value_loss           | 0.00174    |
# ----------------------------------------
#
# ============================================================
#   Step: 70,000 / 1,000,000 (7.0%)
#   Elapsed: 0h 1m 4s | ETA: 0h 14m 11s
#   Speed: 1092 steps/s | Episodes: 175
#   Overall win rate: 66/175 (37.7%)
#   Last 50 ep: win 44.0% | avg len 365 | avg reward -0.120
# ============================================================
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 399         |
# |    ep_rew_mean          | -0.18       |
# | time/                   |             |
# |    fps                  | 1109        |
# |    iterations           | 35          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.020770866 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.312      |
# |    explained_variance   | 0.929       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0156     |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0117     |
# |    value_loss           | 0.00127     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 401         |
# |    ep_rew_mean          | -0.2        |
# | time/                   |             |
# |    fps                  | 1110        |
# |    iterations           | 36          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.025706423 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.403      |
# |    explained_variance   | 0.811       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0185      |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0138     |
# |    value_loss           | 0.00286     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 399         |
# |    ep_rew_mean          | -0.18       |
# | time/                   |             |
# |    fps                  | 1111        |
# |    iterations           | 37          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.030270714 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.34       |
# |    explained_variance   | 0.838       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0126     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.014      |
# |    value_loss           | 0.00145     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 392        |
# |    ep_rew_mean          | -0.22      |
# | time/                   |            |
# |    fps                  | 1112       |
# |    iterations           | 38         |
# |    time_elapsed         | 69         |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.03361795 |
# |    clip_fraction        | 0.142      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.409     |
# |    explained_variance   | 0.787      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0266    |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.016     |
# |    value_loss           | 0.00314    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 385         |
# |    ep_rew_mean          | -0.22       |
# | time/                   |             |
# |    fps                  | 1113        |
# |    iterations           | 39          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.021858102 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.328      |
# |    explained_variance   | 0.781       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0386     |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0124     |
# |    value_loss           | 0.00291     |
# -----------------------------------------
#
# ============================================================
#   Step: 80,000 / 1,000,000 (8.0%)
#   Elapsed: 0h 1m 12s | ETA: 0h 13m 58s
#   Speed: 1097 steps/s | Episodes: 200
#   Overall win rate: 73/200 (36.5%)
#   Last 50 ep: win 36.0% | avg len 404 | avg reward -0.280
# ============================================================
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 385         |
# |    ep_rew_mean          | -0.24       |
# | time/                   |             |
# |    fps                  | 1113        |
# |    iterations           | 40          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.029577572 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.341      |
# |    explained_variance   | 0.905       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.024      |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0147     |
# |    value_loss           | 0.00166     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 385        |
# |    ep_rew_mean          | -0.28      |
# | time/                   |            |
# |    fps                  | 1114       |
# |    iterations           | 41         |
# |    time_elapsed         | 75         |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.02073237 |
# |    clip_fraction        | 0.123      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.36      |
# |    explained_variance   | 0.842      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0174    |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.0107    |
# |    value_loss           | 0.00194    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 382         |
# |    ep_rew_mean          | -0.3        |
# | time/                   |             |
# |    fps                  | 1114        |
# |    iterations           | 42          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.035341315 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.329      |
# |    explained_variance   | 0.909       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00719    |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0153     |
# |    value_loss           | 0.00193     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 370         |
# |    ep_rew_mean          | -0.26       |
# | time/                   |             |
# |    fps                  | 1113        |
# |    iterations           | 43          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.025048086 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.322      |
# |    explained_variance   | 0.69        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.041      |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.013      |
# |    value_loss           | 0.00201     |
# -----------------------------------------
#
# ============================================================
#   Step: 90,000 / 1,000,000 (9.0%)
#   Elapsed: 0h 1m 20s | ETA: 0h 13m 36s
#   Speed: 1114 steps/s | Episodes: 229
#   Overall win rate: 85/229 (37.1%)
#   Last 50 ep: win 34.0% | avg len 367 | avg reward -0.320
# ============================================================
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 372       |
# |    ep_rew_mean          | -0.26     |
# | time/                   |           |
# |    fps                  | 1115      |
# |    iterations           | 44        |
# |    time_elapsed         | 80        |
# |    total_timesteps      | 90112     |
# | train/                  |           |
# |    approx_kl            | 0.0359475 |
# |    clip_fraction        | 0.13      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.316    |
# |    explained_variance   | 0.761     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0184   |
# |    n_updates            | 430       |
# |    policy_gradient_loss | -0.0164   |
# |    value_loss           | 0.00303   |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 366         |
# |    ep_rew_mean          | -0.26       |
# | time/                   |             |
# |    fps                  | 1115        |
# |    iterations           | 45          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.032619886 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.319      |
# |    explained_variance   | 0.905       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.018      |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0159     |
# |    value_loss           | 0.00133     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 374        |
# |    ep_rew_mean          | -0.3       |
# | time/                   |            |
# |    fps                  | 1116       |
# |    iterations           | 46         |
# |    time_elapsed         | 84         |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.03574785 |
# |    clip_fraction        | 0.113      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.336     |
# |    explained_variance   | 0.783      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0202    |
# |    n_updates            | 450        |
# |    policy_gradient_loss | -0.0127    |
# |    value_loss           | 0.00229    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 376         |
# |    ep_rew_mean          | -0.28       |
# | time/                   |             |
# |    fps                  | 1117        |
# |    iterations           | 47          |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.025152192 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.288      |
# |    explained_variance   | 0.791       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0148     |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00892    |
# |    value_loss           | 0.00261     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 380         |
# |    ep_rew_mean          | -0.26       |
# | time/                   |             |
# |    fps                  | 1117        |
# |    iterations           | 48          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.029669467 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.346      |
# |    explained_variance   | 0.888       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0197     |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0147     |
# |    value_loss           | 0.00166     |
# -----------------------------------------
#
# ============================================================
#   Step: 100,000 / 1,000,000 (10.0%)
#   Elapsed: 0h 1m 29s | ETA: 0h 13m 27s
#   Speed: 1115 steps/s | Episodes: 258
#   Overall win rate: 95/258 (36.8%)
#   Last 50 ep: win 38.0% | avg len 339 | avg reward -0.240
# ============================================================
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 371        |
# |    ep_rew_mean          | -0.26      |
# | time/                   |            |
# |    fps                  | 1117       |
# |    iterations           | 49         |
# |    time_elapsed         | 89         |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.03821241 |
# |    clip_fraction        | 0.14       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.368     |
# |    explained_variance   | 0.873      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0244    |
# |    n_updates            | 480        |
# |    policy_gradient_loss | -0.0179    |
# |    value_loss           | 0.00366    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 373         |
# |    ep_rew_mean          | -0.24       |
# | time/                   |             |
# |    fps                  | 1118        |
# |    iterations           | 50          |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.027362583 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.348      |
# |    explained_variance   | 0.816       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0126     |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0116     |
# |    value_loss           | 0.00189     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 367        |
# |    ep_rew_mean          | -0.26      |
# | time/                   |            |
# |    fps                  | 1117       |
# |    iterations           | 51         |
# |    time_elapsed         | 93         |
# |    total_timesteps      | 104448     |
# | train/                  |            |
# |    approx_kl            | 0.04122173 |
# |    clip_fraction        | 0.164      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.375     |
# |    explained_variance   | 0.952      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0447    |
# |    n_updates            | 500        |
# |    policy_gradient_loss | -0.0199    |
# |    value_loss           | 0.0014     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 356         |
# |    ep_rew_mean          | -0.28       |
# | time/                   |             |
# |    fps                  | 1117        |
# |    iterations           | 52          |
# |    time_elapsed         | 95          |
# ...
# |    clip_fraction        | 0.0976     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.162     |
# |    explained_variance   | 0.83       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0226    |
# |    n_updates            | 4720       |
# |    policy_gradient_loss | -0.012     |
# |    value_loss           | 0.00246    |
# ----------------------------------------
#
# ============================================================
#   Step: 970,000 / 1,000,000 (97.0%)
#   Elapsed: 0h 14m 28s | ETA: 0h 0m 26s
#   Speed: 1117 steps/s | Episodes: 3198
#   Overall win rate: 2103/3198 (65.8%)
#   Last 50 ep: win 76.0% | avg len 261 | avg reward 0.520
# ============================================================
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 253        |
# |    ep_rew_mean          | 0.52       |
# | time/                   |            |
# |    fps                  | 1117       |
# |    iterations           | 474        |
# |    time_elapsed         | 868        |
# |    total_timesteps      | 970752     |
# | train/                  |            |
# |    approx_kl            | 0.05007024 |
# |    clip_fraction        | 0.128      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.194     |
# |    explained_variance   | 0.91       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0328    |
# |    n_updates            | 4730       |
# |    policy_gradient_loss | -0.0194    |
# |    value_loss           | 0.00253    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 249         |
# |    ep_rew_mean          | 0.54        |
# | time/                   |             |
# |    fps                  | 1117        |
# |    iterations           | 475         |
# |    time_elapsed         | 870         |
# |    total_timesteps      | 972800      |
# | train/                  |             |
# |    approx_kl            | 0.057437092 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.191      |
# |    explained_variance   | 0.643       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.032      |
# |    n_updates            | 4740        |
# |    policy_gradient_loss | -0.0159     |
# |    value_loss           | 0.00244     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 247         |
# |    ep_rew_mean          | 0.56        |
# | time/                   |             |
# |    fps                  | 1117        |
# |    iterations           | 476         |
# |    time_elapsed         | 872         |
# |    total_timesteps      | 974848      |
# | train/                  |             |
# |    approx_kl            | 0.049104866 |
# |    clip_fraction        | 0.0939      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.147      |
# |    explained_variance   | 0.89        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0163     |
# |    n_updates            | 4750        |
# |    policy_gradient_loss | -0.0126     |
# |    value_loss           | 0.00106     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 247         |
# |    ep_rew_mean          | 0.56        |
# | time/                   |             |
# |    fps                  | 1117        |
# |    iterations           | 477         |
# |    time_elapsed         | 874         |
# |    total_timesteps      | 976896      |
# | train/                  |             |
# |    approx_kl            | 0.047237843 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.165      |
# |    explained_variance   | 0.943       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0246     |
# |    n_updates            | 4760        |
# |    policy_gradient_loss | -0.0169     |
# |    value_loss           | 0.00156     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 248         |
# |    ep_rew_mean          | 0.54        |
# | time/                   |             |
# |    fps                  | 1117        |
# |    iterations           | 478         |
# |    time_elapsed         | 875         |
# |    total_timesteps      | 978944      |
# | train/                  |             |
# |    approx_kl            | 0.028478138 |
# |    clip_fraction        | 0.0981      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.162      |
# |    explained_variance   | 0.919       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00937    |
# |    n_updates            | 4770        |
# |    policy_gradient_loss | -0.0152     |
# |    value_loss           | 0.00167     |
# -----------------------------------------
#
# ============================================================
#   Step: 980,000 / 1,000,000 (98.0%)
#   Elapsed: 0h 14m 37s | ETA: 0h 0m 17s
#   Speed: 1117 steps/s | Episodes: 3240
#   Overall win rate: 2139/3240 (66.0%)
#   Last 50 ep: win 84.0% | avg len 241 | avg reward 0.680
# ============================================================
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 249         |
# |    ep_rew_mean          | 0.6         |
# | time/                   |             |
# |    fps                  | 1117        |
# |    iterations           | 479         |
# |    time_elapsed         | 877         |
# |    total_timesteps      | 980992      |
# | train/                  |             |
# |    approx_kl            | 0.042073287 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.17       |
# |    explained_variance   | 0.917       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0439     |
# |    n_updates            | 4780        |
# |    policy_gradient_loss | -0.0185     |
# |    value_loss           | 0.00116     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 251         |
# |    ep_rew_mean          | 0.62        |
# | time/                   |             |
# |    fps                  | 1117        |
# |    iterations           | 480         |
# |    time_elapsed         | 879         |
# |    total_timesteps      | 983040      |
# | train/                  |             |
# |    approx_kl            | 0.034093205 |
# |    clip_fraction        | 0.0897      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.141      |
# |    explained_variance   | 0.94        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00686    |
# |    n_updates            | 4790        |
# |    policy_gradient_loss | -0.0144     |
# |    value_loss           | 0.00184     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 241         |
# |    ep_rew_mean          | 0.68        |
# | time/                   |             |
# |    fps                  | 1117        |
# |    iterations           | 481         |
# |    time_elapsed         | 881         |
# |    total_timesteps      | 985088      |
# | train/                  |             |
# |    approx_kl            | 0.048027195 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.173      |
# |    explained_variance   | 0.817       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0204     |
# |    n_updates            | 4800        |
# |    policy_gradient_loss | -0.0182     |
# |    value_loss           | 0.00174     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 240        |
# |    ep_rew_mean          | 0.7        |
# | time/                   |            |
# |    fps                  | 1117       |
# |    iterations           | 482        |
# |    time_elapsed         | 883        |
# |    total_timesteps      | 987136     |
# | train/                  |            |
# |    approx_kl            | 0.05790001 |
# |    clip_fraction        | 0.111      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.158     |
# |    explained_variance   | 0.882      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.022     |
# |    n_updates            | 4810       |
# |    policy_gradient_loss | -0.0177    |
# |    value_loss           | 0.000824   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 240         |
# |    ep_rew_mean          | 0.62        |
# | time/                   |             |
# |    fps                  | 1117        |
# |    iterations           | 483         |
# |    time_elapsed         | 885         |
# |    total_timesteps      | 989184      |
# | train/                  |             |
# |    approx_kl            | 0.023659969 |
# |    clip_fraction        | 0.0838      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.147      |
# |    explained_variance   | 0.583       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0232     |
# |    n_updates            | 4820        |
# |    policy_gradient_loss | -0.00912    |
# |    value_loss           | 0.00309     |
# -----------------------------------------
#
# ============================================================
#   Step: 990,000 / 1,000,000 (99.0%)
#   Elapsed: 0h 14m 46s | ETA: 0h 0m 8s
#   Speed: 1117 steps/s | Episodes: 3282
#   Overall win rate: 2172/3282 (66.2%)
#   Last 50 ep: win 80.0% | avg len 233 | avg reward 0.600
# ============================================================
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 243         |
# |    ep_rew_mean          | 0.56        |
# | time/                   |             |
# |    fps                  | 1117        |
# |    iterations           | 484         |
# |    time_elapsed         | 886         |
# |    total_timesteps      | 991232      |
# | train/                  |             |
# |    approx_kl            | 0.048905052 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.172      |
# |    explained_variance   | 0.783       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0313     |
# |    n_updates            | 4830        |
# |    policy_gradient_loss | -0.0164     |
# |    value_loss           | 0.00268     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 248        |
# |    ep_rew_mean          | 0.56       |
# | time/                   |            |
# |    fps                  | 1117       |
# |    iterations           | 485        |
# |    time_elapsed         | 888        |
# |    total_timesteps      | 993280     |
# | train/                  |            |
# |    approx_kl            | 0.03598018 |
# |    clip_fraction        | 0.12       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.198     |
# |    explained_variance   | 0.96       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0379    |
# |    n_updates            | 4840       |
# |    policy_gradient_loss | -0.0178    |
# |    value_loss           | 0.00256    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 244        |
# |    ep_rew_mean          | 0.6        |
# | time/                   |            |
# |    fps                  | 1117       |
# |    iterations           | 486        |
# |    time_elapsed         | 890        |
# |    total_timesteps      | 995328     |
# | train/                  |            |
# |    approx_kl            | 0.04535412 |
# |    clip_fraction        | 0.0869     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.144     |
# |    explained_variance   | 0.755      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0131    |
# |    n_updates            | 4850       |
# |    policy_gradient_loss | -0.0144    |
# |    value_loss           | 0.00206    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 250         |
# |    ep_rew_mean          | 0.56        |
# | time/                   |             |
# |    fps                  | 1117        |
# |    iterations           | 487         |
# |    time_elapsed         | 892         |
# |    total_timesteps      | 997376      |
# | train/                  |             |
# |    approx_kl            | 0.038311914 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.157      |
# |    explained_variance   | 0.855       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0251     |
# |    n_updates            | 4860        |
# |    policy_gradient_loss | -0.0144     |
# |    value_loss           | 0.00107     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 249        |
# |    ep_rew_mean          | 0.56       |
# | time/                   |            |
# |    fps                  | 1117       |
# |    iterations           | 488        |
# |    time_elapsed         | 894        |
# |    total_timesteps      | 999424     |
# | train/                  |            |
# |    approx_kl            | 0.03499493 |
# |    clip_fraction        | 0.115      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.191     |
# |    explained_variance   | 0.957      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0283    |
# |    n_updates            | 4870       |
# |    policy_gradient_loss | -0.0183    |
# |    value_loss           | 0.00203    |
# ----------------------------------------
#
# ============================================================
#   Step: 1,000,000 / 1,000,000 (100.0%)
#   Elapsed: 0h 14m 55s | ETA: 0h 0m 0s
#   Speed: 1117 steps/s | Episodes: 3316
#   Overall win rate: 2197/3316 (66.3%)
#   Last 50 ep: win 70.0% | avg len 271 | avg reward 0.400
# ============================================================
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 253        |
# |    ep_rew_mean          | 0.58       |
# | time/                   |            |
# |    fps                  | 1117       |
# |    iterations           | 489        |
# |    time_elapsed         | 895        |
# |    total_timesteps      | 1001472    |
# | train/                  |            |
# |    approx_kl            | 0.03181176 |
# |    clip_fraction        | 0.11       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.194     |
# |    explained_variance   | 0.766      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00986   |
# |    n_updates            | 4880       |
# |    policy_gradient_loss | -0.0145    |
# |    value_loss           | 0.00297    |
# ----------------------------------------
#
# ############################################################
#   TRAINING COMPLETE
#   Total time: 0.2 hours
#   Total episodes: 3322
#   Final win rate: 66.3%
# ############################################################
#
# Model saved to catan_ppo_vs_weighted.zip

# %%
import matplotlib.pyplot as plt

rewards = callback.episode_rewards
lengths = callback.episode_lengths
window = 50

if len(rewards) >= window:
    smoothed = np.convolve(rewards, np.ones(window)/window, mode='valid')
    smoothed_len = np.convolve(lengths, np.ones(window)/window, mode='valid')
    wins_binary = [1 if r > 0 else 0 for r in rewards]
    win_rate = np.convolve(wins_binary, np.ones(window)/window, mode='valid')

    fig, axes = plt.subplots(1, 3, figsize=(18, 5))

    axes[0].plot(smoothed)
    axes[0].set_title("Episode Reward (50-ep rolling avg)")
    axes[0].set_xlabel("Episode")
    axes[0].set_ylabel("Reward")
    axes[0].axhline(y=0, color='gray', linestyle='--', alpha=0.5)

    axes[1].plot(smoothed_len)
    axes[1].set_title("Episode Length (50-ep rolling avg)")
    axes[1].set_xlabel("Episode")
    axes[1].set_ylabel("Steps")

    axes[2].plot(100 * win_rate)
    axes[2].set_title("Win Rate vs WeightedRandom (50-ep rolling avg)")
    axes[2].set_xlabel("Episode")
    axes[2].set_ylabel("Win Rate %")
    axes[2].axhline(y=50, color='red', linestyle='--', alpha=0.5, label='50%')
    axes[2].legend()

    plt.tight_layout()
    plt.show()

    print(f"Total episodes: {len(rewards)}")
    print(f"Final 50-ep win rate: {100*win_rate[-1]:.1f}%")
    print(f"Final 50-ep avg reward: {smoothed[-1]:.3f}")
else:
    print(f"Only {len(rewards)} episodes, need {window} to plot")
# Out:
# Total episodes: 3322
# Final 50-ep win rate: 74.0%
# Final 50-ep avg reward: 0.480

# %%
SAVE_PATH = "catan_ppo_vs_weighted"
N_GAMES = 500

model = MaskablePPO.load(SAVE_PATH)

eval_env = gymnasium.make(
    "catanatron-v1",
    config={"enemies": [WeightedRandomPlayer(Color.RED)]},
)

wins, losses, draws = 0, 0, 0
ep_lengths = []
ep_rewards = []

print(f"Evaluating over {N_GAMES} games vs WeightedRandomPlayer...")
start = time.time()

for i in range(N_GAMES):
    obs, info = eval_env.reset()
    done = False
    total_reward = 0
    steps = 0

    while not done:
        valid = eval_env.unwrapped.get_valid_actions()
        mask = np.zeros(eval_env.action_space.n, dtype=bool)
        if len(valid) > 0:
            mask[valid] = True
        else:
            mask[:] = True

        action, _ = model.predict(obs, action_masks=mask, deterministic=True)
        obs, reward, terminated, truncated, info = eval_env.step(int(action))
        total_reward += reward
        steps += 1
        done = terminated or truncated

    ep_lengths.append(steps)
    ep_rewards.append(total_reward)
    if total_reward > 0:
        wins += 1
    elif total_reward < 0:
        losses += 1
    else:
        draws += 1

    if (i + 1) % 50 == 0:
        elapsed = time.time() - start
        eta = (N_GAMES - i - 1) / ((i + 1) / elapsed)
        print(f"  [{i+1}/{N_GAMES}] Win rate: {100*wins/(i+1):.1f}% | ETA: {eta:.0f}s")

eval_env.close()
elapsed = time.time() - start

wr = wins / N_GAMES
z = 1.96
d = 1 + z**2 / N_GAMES
center = (wr + z**2 / (2 * N_GAMES)) / d
spread = z * np.sqrt((wr * (1 - wr) + z**2 / (4 * N_GAMES)) / N_GAMES) / d

print(f"\n{'='*60}")
print(f"  RESULTS vs WeightedRandomPlayer ({N_GAMES} games, {elapsed:.0f}s)")
print(f"  Wins: {wins} | Losses: {losses} | Draws: {draws}")
print(f"  Win rate: {100*wr:.1f}%")
print(f"  95% CI:   [{100*max(0,center-spread):.1f}%, {100*min(1,center+spread):.1f}%]")
print(f"  Avg episode length: {np.mean(ep_lengths):.0f}")
print(f"  Avg reward: {np.mean(ep_rewards):.3f}")
print(f"{'='*60}")
# Out:
# Evaluating over 500 games vs WeightedRandomPlayer...
#   [50/500] Win rate: 64.0% | ETA: 32s
#   [100/500] Win rate: 68.0% | ETA: 27s
#   [150/500] Win rate: 66.7% | ETA: 24s
#   [200/500] Win rate: 68.0% | ETA: 20s
#   [250/500] Win rate: 67.6% | ETA: 17s
#   [300/500] Win rate: 69.0% | ETA: 13s
#   [350/500] Win rate: 68.6% | ETA: 10s
#   [400/500] Win rate: 68.0% | ETA: 7s
#   [450/500] Win rate: 68.4% | ETA: 3s
#   [500/500] Win rate: 68.6% | ETA: 0s
#
# ============================================================
#   RESULTS vs WeightedRandomPlayer (500 games, 34s)
#   Wins: 343 | Losses: 157 | Draws: 0
#   Win rate: 68.6%
#   95% CI:   [64.4%, 72.5%]
#   Avg episode length: 270
#   Avg reward: 0.372
# ============================================================
